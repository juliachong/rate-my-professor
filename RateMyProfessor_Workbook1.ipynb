# %%
import pandas as pd
import json
import requests
import time
import numpy as np
import re

# %% [markdown]
# # Data Pull/Parse

# %%
def get_data(school_id):
    id = school_id
    url_ex = f'http://www.ratemyprofessors.com/filter/professor/?&page=1&filter=teacherlastname_sort_s+asc&query=*%3A*&queryoption=TEACHER&queryBy=schoolId&sid={id}'
    response = requests.get(url_ex)
    data = json.loads(response.text)
    num_of_professors = data['searchResultsTotal']
    num_divided = num_of_professors / 20
    
    if isinstance(num_divided, float) == True:
        num_divided = int(num_divided + 1)
        
    professors = []    
    for i in range(1, num_divided):
        id = school_id
        url = f'http://www.ratemyprofessors.com/filter/professor/?&page={i}&filter=teacherlastname_sort_s+asc&query=*%3A*&queryoption=TEACHER&queryBy=schoolId&sid={id}'
        response = requests.get(url)
        data = json.loads(response.text)
        professors.append(data)
    new_list = []
    for i in range(len(professors)):
        prof_data = professors[i]['professors']
        new_list.append(prof_data)
    prof = []
    for i in range(len(new_list)):
        a = new_list[i]
        for j in range(len(a)):
            b = a[j]
            prof.append(b)
    
    prof_list = []
    
    for i in range(len(prof)):
            overall_rating = prof[i]['overall_rating']
            if overall_rating == 'N/A':
                continue
            else:
                school = prof[i]['institution_name']
                dept = prof[i]['tDept']
                name = prof[i]['tLname'] + ' ' + prof[i]['tFname']
                num_ratings = prof[i]['tNumRatings']
                rating = prof[i]['overall_rating']
                prof_tuple = (school, name, dept, float(rating), num_ratings)
                prof_list.append(prof_tuple)
    return prof_list

# %%
prof_list = get_data(758)

# %%
prof_list
# Out:
# [('Pennsylvania State University', 'Aalberts Robert', 'Law', 3.5, 15),
#  ('Pennsylvania State University', 'Aas Erik', 'Mathematics', 2.3, 3),
#  ('Pennsylvania State University', 'Abaci Uygar', 'Philosophy', 4.3, 11),
#  ('Pennsylvania State University', 'Abalo Kodzovi', 'Economics', 2.8, 6),
#  ('Pennsylvania State University',
#   'Abar Caitlin',
#   'Human Development',
#   4.7,
#   3),
#  ('Pennsylvania State University',
#   'Abbaas Omar',
#   'Industrial Engineering',
#   3.6,
#   12),
#  ('Pennsylvania State University', 'Abdullah Amir', 'Theater', 4.0, 1),
#  ('Pennsylvania State University', 'Abdullah Ayesha', 'Philosophy', 3.6, 6),
#  ('Pennsylvania State University', 'Abdullah Gary', 'Communication', 5.0, 2),
#  ('Pennsylvania State University', 'Abel Jessamyn', 'History', 4.0, 9),
#  ('Pennsylvania State University', 'Abel Jonathan', 'Literature', 3.8, 17),
#  ('Pennsylvania State University', 'Abelbeck Hannah', 'English', 2.5, 7),
#  ('Pennsylvania State University', 'Abler David', 'Economics', 2.5, 9),
#  ('Pennsylvania State University',
#   'Aboulafia Mitchell',
#   'Philosophy',
#   4.4,
#   11),
#  ('Pennsylvania State University', 'Abrams Marc', 'Earth Science', 4.3, 12),
#  ('Pennsylvania State University',
#   'Abrokwaa Clemente',
#   "Women's Studies",
#   3.2,
#   73),
#  ('Pennsylvania State University', 'Acharya Raj', 'Computer Science', 3.0, 3),
#  ('Pennsylvania State University', 'Achord Samuel', 'Mathematics', 5.0, 12),
#  ('Pennsylvania State University', 'Acimovic Jason', 'Business', 4.2, 23),
#  ('Pennsylvania State University',
#   'Adair James',
#   'Materials Engineering',
#   3.1,
#   9),
#  ('Pennsylvania State University', 'Adams Matthew', 'Classics', 4.3, 15),
#  ('Pennsylvania State University', 'Adams Tommy', 'Communication', 3.1, 11),
#  ('Pennsylvania State University', 'Adams Heather', 'English', 4.8, 3),
#  ('Pennsylvania State University', 'Adams Sarah', 'English', 4.5, 2),
#  ('Pennsylvania State University', 'Adams J.', 'Mathematics', 4.0, 1),
#  ('Pennsylvania State University', 'Adams Katherine', 'Psychology', 1.0, 2),
#  ('Pennsylvania State University', 'Adams Cynthia', 'Nutrition', 3.4, 7),
#  ('Pennsylvania State University', 'Adams Jeremy', 'Philosophy', 2.3, 3),
#  ('Pennsylvania State University', 'Adams Reginald', 'Psychology', 3.7, 18),
#  ('Pennsylvania State University', 'Adams Katharine', 'Psychology', 1.0, 1),
#  ('Pennsylvania State University', 'Ader David', 'Sociology', 4.8, 5),
#  ('Pennsylvania State University',
#   'Ades Sarah',
#   'Biological Sciences',
#   3.5,
#   9),
#  ('Pennsylvania State University', 'Adler Eliyana', 'Jewish Studies', 2.2, 13),
#  ('Pennsylvania State University', 'Adnet Gauthier', 'French', 5.0, 2),
#  ('Pennsylvania State University',
#   'Aeschbacher Peter',
#   'Architecture',
#   4.4,
#   13),
#  ('Pennsylvania State University', 'Affleck John', 'Communication', 5.0, 2),
#  ('Pennsylvania State University', 'Aggleton Sabrina', 'Philosophy', 2.4, 4),
#  ('Pennsylvania State University', 'Aggleton Derek', 'Philosophy', 3.5, 21),
#  ('Pennsylvania State University', 'Aggon Norman', 'Business', 3.5, 74),
#  ('Pennsylvania State University', 'Agil Rania', 'Food Science', 3.7, 6),
#  ('Pennsylvania State University', 'Agler David', 'Philosophy', 4.5, 24),
#  ('Pennsylvania State University', 'Agnosteva Delina', 'Economics', 3.8, 4),
#  ('Pennsylvania State University', 'Agrawal Dinesh', 'Engineering', 3.4, 3),
#  ('Pennsylvania State University', 'Aguilo-Perez Emily', 'English', 4.7, 3),
#  ('Pennsylvania State University',
#   'Ahern Frank',
#   'Biological Sciences',
#   3.8,
#   16),
#  ('Pennsylvania State University', 'Ahern Lee', 'Communication', 3.6, 35),
#  ('Pennsylvania State University',
#   'Ahlgren Mike',
#   'Hotel & Restaurant Management',
#   4.3,
#   8),
#  ('Pennsylvania State University', 'Ahlin Eileen', 'Criminal Justice', 4.0, 1),
#  ('Pennsylvania State University', 'Ahlkvist Jarl', 'Not Specified', 2.5, 32),
#  ('Pennsylvania State University', 'Ahmad Lameese', 'Arabic', 5.0, 2),
#  ('Pennsylvania State University',
#   'Aigbedion Irenae',
#   'Comparative Literature',
#   5.0,
#   1),
#  ('Pennsylvania State University',
#   'Aileo Nathan',
#   'Information Science',
#   4.4,
#   5),
#  ('Pennsylvania State University', 'Akech Daniel', 'Mathematics', 3.0, 2),
#  ('Pennsylvania State University',
#   'Akgun Mahir',
#   'Information Sciences  Technology',
#   1.2,
#   18),
#  ('Pennsylvania State University', 'Akin Zafer', 'Economics', 3.1, 5),
#  ('Pennsylvania State University', 'Akritas Michael', 'Mathematics', 2.2, 37),
#  ('Pennsylvania State University',
#   'Aksoy Deniz',
#   'Political Science',
#   3.7,
#   12),
#  ('Pennsylvania State University',
#   'Al Ariss Akram',
#   'Labor  Employment Relations',
#   3.7,
#   4),
#  ('Pennsylvania State University',
#   'Al-gharaib Meshal',
#   'Earth Science',
#   3.8,
#   17),
#  ('Pennsylvania State University', 'Alansari Nawaf', 'Mathematics', 4.2, 6),
#  ('Pennsylvania State University', 'Albert Reka', 'Physics', 5.0, 2),
#  ('Pennsylvania State University', 'Albert Jana', 'German', 4.7, 3),
#  ('Pennsylvania State University', 'Albert Istvan', 'Biochemistry', 3.7, 6),
#  ('Pennsylvania State University', 'Alderman Robert', 'English', 4.5, 13),
#  ('Pennsylvania State University', 'Alderman Christine', 'English', 5.0, 1),
#  ('Pennsylvania State University', 'Alessandri Mary', 'Philosophy', 3.9, 8),
#  ('Pennsylvania State University', 'Alexander Stephon', 'Physics', 3.1, 5),
#  ('Pennsylvania State University', 'Alexander Lacy', 'Kinesiology', 4.8, 2),
#  ('Pennsylvania State University', 'Alexander Angela', 'History', 2.0, 3),
#  ('Pennsylvania State University', 'Alfaro Urena Alonso', 'Economics', 2.8, 3),
#  ('Pennsylvania State University', 'Ali Rahan', 'Psychology', 4.4, 144),
#  ('Pennsylvania State University', 'Ali Nageeb', 'Economics', 1.8, 2),
#  ('Pennsylvania State University', 'Alipour Kent', 'Psychology', 5.0, 2),
#  ('Pennsylvania State University', 'Allara David', 'Chemistry', 2.6, 5),
#  ('Pennsylvania State University', 'Allcock Harry', 'Chemistry', 3.5, 2),
#  ('Pennsylvania State University',
#   'Allen Doug',
#   'Labor & Employment Relations',
#   2.7,
#   14),
#  ('Pennsylvania State University',
#   'Allen Douglas',
#   'Labor & Employment Relations',
#   1.0,
#   1),
#  ('Pennsylvania State University', 'Allen Patrick', 'English', 4.5, 20),
#  ('Pennsylvania State University',
#   'Allen  Doug ',
#   'Labor  Employment Relations',
#   4.5,
#   1),
#  ('Pennsylvania State University', 'Alley Michael', 'Communication', 4.7, 16),
#  ('Pennsylvania State University', 'Alley Richard', 'Geology', 4.3, 75),
#  ('Pennsylvania State University',
#   'Alloway Kevin',
#   'Biological Sciences',
#   3.0,
#   4),
#  ('Pennsylvania State University',
#   'Almeida David',
#   'Human Development',
#   4.2,
#   28),
#  ('Pennsylvania State University',
#   'Almekkawy Mohamed',
#   'Computer Science',
#   4.1,
#   26),
#  ('Pennsylvania State University', 'Aloia Lindsey', 'Communication', 4.7, 16),
#  ('Pennsylvania State University',
#   'Alptekinoglu Aydin',
#   'Supply Chain Management',
#   5.0,
#   1),
#  ('Pennsylvania State University', 'Alrawi Noora ', 'Arabic', 2.8, 2),
#  ('Pennsylvania State University', 'Alter Theodore', 'Economics', 3.8, 8),
#  ('Pennsylvania State University', 'Altman Naomi', 'Statistics', 1.9, 9),
#  ('Pennsylvania State University', 'Alumasa John', 'Biochemistry', 5.0, 1),
#  ('Pennsylvania State University', 'Alvarez Jose', 'Spanish', 3.9, 6),
#  ('Pennsylvania State University', 'Alvis-Ruiz Erin', 'Spanish', 3.5, 22),
#  ('Pennsylvania State University', 'Alvis-Ruiz Carlos', 'Spanish', 4.2, 19),
#  ('Pennsylvania State University', 'Alwin Duane', 'Sociology', 3.0, 2),
#  ('Pennsylvania State University', 'Aly Reham', 'Arabic', 5.0, 3),
#  ('Pennsylvania State University', 'Amano Yuki', 'Japanese', 4.3, 9),
#  ('Pennsylvania State University', 'Amato Paul', 'Sociology', 5.0, 1),
#  ('Pennsylvania State University', 'Amburgy Patricia', 'Fine Arts', 4.8, 7),
#  ('Pennsylvania State University', 'Ammon Charles', 'Earth Science', 3.4, 14),
#  ('Pennsylvania State University', 'Amory Michael', 'French', 5.0, 1),
#  ('Pennsylvania State University', 'Amsden Brian', 'Communication', 4.5, 1),
#  ('Pennsylvania State University',
#   'Anandakrishnan Sridhar',
#   'Geology',
#   3.3,
#   23),
#  ('Pennsylvania State University',
#   'Ancic Ivana',
#   'Comparative Literature',
#   5.0,
#   3),
#  ('Pennsylvania State University', 'Anders Abram', 'English', 3.6, 7),
#  ('Pennsylvania State University', 'Andersen Carl', 'English', 4.3, 17),
#  ('Pennsylvania State University', 'Anderson Joel', 'Mathematics', 3.5, 34),
#  ('Pennsylvania State University', 'Anderson Claudia', 'Education', 4.1, 16),
#  ('Pennsylvania State University', 'Anderson Martha', 'Physical Ed', 4.0, 19),
#  ('Pennsylvania State University', 'Anderson Beth', 'Chemistry', 5.0, 5),
#  ('Pennsylvania State University', 'Anderson Emily', 'English', 4.8, 2),
#  ('Pennsylvania State University', 'Anderson Katherine', 'German', 4.0, 5),
#  ('Pennsylvania State University', 'Anderson Rebecca', 'English', 4.0, 10),
#  ('Pennsylvania State University',
#   'Anderson Brita',
#   'Communication Arts',
#   1.9,
#   8),
#  ('Pennsylvania State University',
#   'Anderson Deborah',
#   'Labor & Employment Relations',
#   5.0,
#   1),
#  ('Pennsylvania State University', 'Anderson Brittany', 'Chemistry', 2.7, 6),
#  ('Pennsylvania State University', 'Anderson Drew', 'Geography', 5.0, 4),
#  ('Pennsylvania State University', 'Anderson Randi', 'English', 1.5, 2),
#  ('Pennsylvania State University', 'Anderson Carl', 'English', 4.3, 6),
#  ('Pennsylvania State University', 'Andiappan Meena', 'Management', 5.0, 2),
#  ('Pennsylvania State University',
#   'Andrejewski Robert',
#   'Recreation, Parks, & Tourism',
#   4.5,
#   3),
#  ('Pennsylvania State University', 'Andrew Benjamin', 'Art', 2.2, 4),
#  ('Pennsylvania State University', 'Andrews Kim', 'English', 4.9, 8),
#  ('Pennsylvania State University',
#   'Andrews J Scott',
#   'Communication',
#   4.6,
#   12),
#  ('Pennsylvania State University',
#   'Andrews David',
#   'Labor  Employment Relations',
#   5.0,
#   1),
#  ('Pennsylvania State University', 'Andrews George', 'Mathematics', 4.7, 12),
#  ('Pennsylvania State University', 'Andreyo James', 'Communication', 3.4, 9),
#  ('Pennsylvania State University', 'Andris Clio', 'Geography', 4.0, 19),
#  ('Pennsylvania State University', 'Andrus Nancy', 'French', 5.0, 1),
#  ('Pennsylvania State University', 'Aneckstein Dave', 'Communication', 4.1, 5),
#  ('Pennsylvania State University', 'Anesko Michael', 'English', 2.9, 23),
#  ('Pennsylvania State University',
#   'Anghelcev George',
#   'Communication',
#   4.2,
#   21),
#  ('Pennsylvania State University',
#   'Anner Mark',
#   'Labor & Employment Relations',
#   4.3,
#   16),
#  ('Pennsylvania State University', 'Anya Uju', 'Education', 5.0, 1),
#  ('Pennsylvania State University',
#   'Anzman Steph',
#   'Human Development',
#   4.3,
#   2),
#  ('Pennsylvania State University', 'Apfelbaum Joseph', 'Music', 2.1, 8),
#  ('Pennsylvania State University', 'Appel Molly', 'English', 1.9, 7),
#  ('Pennsylvania State University', 'Appelman Alyssa', 'Communication', 3.4, 5),
#  ('Pennsylvania State University',
#   'Applegate Patrick',
#   'Earth Science',
#   2.0,
#   1),
#  ('Pennsylvania State University',
#   'Aradillas-Lopez Andres',
#   'Economics',
#   3.2,
#   6),
#  ('Pennsylvania State University', 'Archangeli Melanie', 'Spanish', 4.4, 17),
#  ('Pennsylvania State University',
#   'Arguelles Andrea',
#   'Engineering, Science, & Mechanics',
#   5.0,
#   3),
#  ('Pennsylvania State University',
#   'Aristarkhova Irin',
#   "Women's Studies",
#   4.0,
#   5),
#  ('Pennsylvania State University',
#   'Armaou Antonios',
#   'Chemical Engineering',
#   2.5,
#   10),
#  ('Pennsylvania State University', 'Armas Alexandra', 'Spanish', 4.1, 4),
#  ('Pennsylvania State University',
#   'Armillas-Tiseyra Magali',
#   'Comparative Literature',
#   3.6,
#   7),
#  ('Pennsylvania State University', 'Armstrong Dan', 'Music', 4.5, 3),
#  ('Pennsylvania State University', 'Arnold Steven', 'Mathematics', 1.4, 24),
#  ('Pennsylvania State University', 'Arora Sonny', 'Mathematics', 4.8, 4),
#  ('Pennsylvania State University', 'Arriagada Carlos', 'Spanish', 3.5, 2),
#  ('Pennsylvania State University', 'Arsie Alessandro', 'Mathematics', 4.1, 8),
#  ('Pennsylvania State University', 'Arteca Richard', 'Horticulture', 3.3, 76),
#  ('Pennsylvania State University', 'Artemiou Andreas', 'Statistics', 4.8, 10),
#  ('Pennsylvania State University', 'Arthur Michael', 'Earth Science', 4.4, 39),
#  ('Pennsylvania State University', 'Aryal Gaurab', 'Economics', 2.6, 12),
#  ('Pennsylvania State University', 'Asbury John', 'Chemistry', 2.9, 91),
#  ('Pennsylvania State University', 'Ashok Srivastava', 'Engineering', 2.0, 3),
#  ('Pennsylvania State University',
#   'Assmann Sarah',
#   'Biological Sciences',
#   3.7,
#   10),
#  ('Pennsylvania State University',
#   'Atkins Burton',
#   'Political Science',
#   4.7,
#   7),
#  ('Pennsylvania State University',
#   'Attwell-Duval Dylan',
#   'Mathematics',
#   3.0,
#   11),
#  ('Pennsylvania State University', 'Atwill David', 'History', 3.9, 38),
#  ('Pennsylvania State University', 'Auday Eran', 'Psychology', 4.0, 1),
#  ('Pennsylvania State University',
#   'August Avery',
#   'Veterinary Sciences',
#   4.0,
#   9),
#  ('Pennsylvania State University',
#   'Auhl Richard',
#   'Aerospace Engineering',
#   3.8,
#   2),
#  ('Pennsylvania State University', 'Aumiller Dane', 'Kinesiology', 4.9, 15),
#  ('Pennsylvania State University',
#   'Aumiller Betsy',
#   'Behavioral Sciences',
#   4.0,
#   2),
#  ('Pennsylvania State University', 'Aungst Stan', 'Computer Science', 2.3, 47),
#  ('Pennsylvania State University',
#   'Aungst William',
#   'Communication Arts',
#   5.0,
#   1),
#  ('Pennsylvania State University',
#   'Aurand Gary',
#   'Chemical Engineering',
#   1.0,
#   1),
#  ('Pennsylvania State University', 'Ausherman James', 'English', 4.4, 23),
#  ('Pennsylvania State University', 'Austin Kimberly', 'Business', 4.8, 29),
#  ('Pennsylvania State University', 'Austin Stefanie', 'Mathematics', 4.3, 3),
#  ('Pennsylvania State University', 'Authier J. Marc', 'French', 4.4, 13),
#  ('Pennsylvania State University', 'Avery Julian', 'Animal Science', 4.0, 5),
#  ('Pennsylvania State University', 'Aviles Reggie', 'Architecture', 3.2, 7),
#  ('Pennsylvania State University', 'Avramova Maria', 'Engineering', 3.2, 6),
#  ('Pennsylvania State University',
#   'Awadelkarim Osama',
#   'Engineering',
#   3.7,
#   20),
#  ('Pennsylvania State University',
#   'Axtell Michael',
#   'Biological Sciences',
#   3.5,
#   28),
#  ('Pennsylvania State University',
#   'Ayala Luis',
#   'Mineral Engineering',
#   4.0,
#   10),
#  ('Pennsylvania State University',
#   'Ayan Bugra',
#   'Engineering Science amp Mechanics',
#   5.0,
#   2),
#  ('Pennsylvania State University',
#   'Aydin Kultegin',
#   'Electrical Engineering',
#   2.0,
#   13),
#  ('Pennsylvania State University', 'Azar Sandra', 'Psychology', 2.4, 27),
#  ('Pennsylvania State University', 'Babb David', 'Earth Science', 3.0, 48),
#  ('Pennsylvania State University', 'Babcock Edward', 'Accounting', 4.4, 36),
#  ('Pennsylvania State University', 'Babcock Jan', 'English', 4.2, 35),
#  ('Pennsylvania State University', 'Babich Andrea', 'English', 3.9, 6),
#  ('Pennsylvania State University',
#   'Babitzke Paul',
#   'Biological Sciences',
#   3.3,
#   40),
#  ('Pennsylvania State University', 'Babu G. Jogesh', 'Statistics', 2.0, 14),
#  ('Pennsylvania State University',
#   'Bacastow Todd',
#   'Information Science',
#   3.7,
#   9),
#  ('Pennsylvania State University', 'Bachner Andrea', 'Film', 3.5, 6),
#  ('Pennsylvania State University',
#   'Backenstoe Thomas E.',
#   'Behavioral Sciences',
#   4.3,
#   31),
#  ('Pennsylvania State University', 'Bacue Aaron', 'Communication', 4.8, 8),
#  ('Pennsylvania State University',
#   'Badenhorst Paul',
#   'Curriculum  Instruction',
#   4.5,
#   1),
#  ('Pennsylvania State University', 'Badenhorst Pauli', 'Education', 4.5, 2),
#  ('Pennsylvania State University',
#   'Baderoon Gabeba',
#   'African-American Studies',
#   4.3,
#   9),
#  ('Pennsylvania State University', 'Bae Young Han', 'Marketing', 5.0, 2),
#  ('Pennsylvania State University',
#   'Bae-Dimitriadis Michelle',
#   'Art Education',
#   3.2,
#   5),
#  ('Pennsylvania State University',
#   'Bagby John',
#   'Information Science',
#   3.0,
#   28),
#  ('Pennsylvania State University', 'Bagyan Armine', 'Statistics', 2.8, 34),
#  ('Pennsylvania State University',
#   'Bahnfleth William',
#   'Architectural Engineering',
#   4.0,
#   2),
#  ('Pennsylvania State University', 'Bahry Donna', 'Political Science', 4.5, 8),
#  ('Pennsylvania State University', 'Bai Qichuan', 'Mathematics', 1.0, 1),
#  ('Pennsylvania State University', 'Bai Lu', 'Biochemistry', 3.2, 8),
#  ('Pennsylvania State University', 'Bai Steve', 'Statistics', 4.3, 2),
#  ('Pennsylvania State University', 'Bai Sunhye', 'Human Development', 4.3, 3),
#  ('Pennsylvania State University', 'Bailey Indira', 'Visual Arts', 1.3, 3),
#  ('Pennsylvania State University',
#   'Baird Tim',
#   'Landscape Architecture & Regional Planning',
#   3.5,
#   1),
#  ('Pennsylvania State University', 'Baka Jennifer', 'Geography', 2.8, 4),
#  ('Pennsylvania State University', 'Baker Eleanor', 'English', 2.5, 25),
#  ('Pennsylvania State University', 'Baker David', 'Education', 2.5, 3),
#  ('Pennsylvania State University', 'Baker Brian', 'Sociology', 4.3, 67),
#  ('Pennsylvania State University', 'Baker Lehtonen Kelly', 'English', 3.5, 4),
#  ('Pennsylvania State University', 'Bakis Charles', 'Engineering', 4.8, 3),
#  ('Pennsylvania State University', 'Bakke Alyssa', 'Food Science', 4.0, 1),
#  ('Pennsylvania State University',
#   'Bakowicz Matthew',
#   'Recreation Parks  Tourism',
#   4.8,
#   4),
#  ('Pennsylvania State University', 'Bakshi Alok', 'Mathematics', 4.4, 14),
#  ('Pennsylvania State University', 'Balachandran Jyoti', 'History', 4.5, 2),
#  ('Pennsylvania State University',
#   'Balakian Sophia',
#   'African-American Studies',
#   4.2,
#   5),
#  ('Pennsylvania State University',
#   'Balay Joey Micheal',
#   'Philosophy',
#   3.9,
#   11),
#  ('Pennsylvania State University', 'Balay Jillian', 'Art History', 1.0, 2),
#  ('Pennsylvania State University', 'Baldanza Kathlene', 'History', 4.9, 5),
#  ('Pennsylvania State University', 'Baldi Philip', 'Classics', 4.0, 14),
#  ('Pennsylvania State University', 'Baldwin Diane', 'Kinesiology', 5.0, 4),
#  ('Pennsylvania State University', 'Baliff Serge', 'Mathematics', 4.8, 10),
#  ('Pennsylvania State University',
#   'Ballenger Jesse',
#   'Social Science',
#   3.9,
#   18),
#  ('Pennsylvania State University', 'Balliett Timothy', 'Education', 4.2, 3),
#  ('Pennsylvania State University', 'Ballora Mark', 'Music', 2.8, 48),
#  ('Pennsylvania State University',
#   'Bamaca Mayra',
#   'Human Development',
#   2.7,
#   12),
#  ('Pennsylvania State University', 'Bandman Tatiana', 'Mathematics', 1.2, 6),
#  ('Pennsylvania State University',
#   'Bandyopadhyay Shreejit',
#   'Mathematics',
#   2.6,
#   9),
#  ('Pennsylvania State University', 'Banfield Ian', 'Mathematics', 1.9, 8),
#  ('Pennsylvania State University', 'Bang Seunghoon', 'Mathematics', 4.0, 91),
#  ('Pennsylvania State University', 'Banka Rachel', 'English', 4.0, 5),
#  ('Pennsylvania State University',
#   'Bannangkoon Pichkitti',
#   'Mathematics',
#   4.8,
#   11),
#  ('Pennsylvania State University',
#   'Bannano Alessandro',
#   'Agriculture',
#   3.0,
#   2),
#  ('Pennsylvania State University', 'Bannon Peter', 'Meteorology', 2.2, 13),
#  ('Pennsylvania State University', 'Bansal Saurabh', 'Business', 4.8, 13),
#  ('Pennsylvania State University', 'Banyaga Augustin', 'Mathematics', 2.1, 22),
#  ('Pennsylvania State University', 'Banyas Kyle', 'Chemistry', 5.0, 3),
#  ('Pennsylvania State University', 'Bao Rui', 'Mathematics', 1.5, 8),
#  ('Pennsylvania State University', 'Bao Le', 'Statistics', 4.9, 12),
#  ('Pennsylvania State University', 'Baptista Gregory', 'English', 4.9, 8),
#  ('Pennsylvania State University', 'Baptiste Ian', 'Education', 2.4, 19),
#  ('Pennsylvania State University', 'Bara Rachel', 'English', 3.2, 4),
#  ('Pennsylvania State University', 'Barata Raquel', 'Statistics', 5.0, 1),
#  ('Pennsylvania State University', 'Barber Greg', 'Chemistry', 3.5, 38),
#  ('Pennsylvania State University',
#   'Barbieri Anthony',
#   'Communication',
#   3.4,
#   33),
#  ('Pennsylvania State University',
#   'Barchinger Sarah',
#   'Biological Sciences',
#   5.0,
#   1),
#  ('Pennsylvania State University', 'Barger Lori', 'Communication', 5.0, 2),
#  ('Pennsylvania State University',
#   'Barger David',
#   'Communication Arts',
#   3.0,
#   4),
#  ('Pennsylvania State University',
#   'Baril Megan',
#   'Human Development',
#   3.7,
#   14),
#  ('Pennsylvania State University', 'Barker Joe', 'Philosophy', 4.8, 8),
#  ('Pennsylvania State University', 'Barkley Mathew', 'Business', 5.0, 1),
#  ('Pennsylvania State University',
#   'Barkley Mathew',
#   'Labor amp Employment Relations',
#   5.0,
#   1),
#  ('Pennsylvania State University',
#   'Barlett A.L.',
#   'Hotel & Restaurant Management',
#   3.8,
#   12),
#  ('Pennsylvania State University',
#   'Barlow Jesse',
#   'Computer Science',
#   3.6,
#   10),
#  ('Pennsylvania State University', 'Barlow Brad', 'Astronomy', 4.7, 13),
#  ('Pennsylvania State University', 'Barnard Mary', 'Spanish', 4.3, 12),
#  ('Pennsylvania State University', 'Barnhart James', 'History', 3.8, 13),
#  ('Pennsylvania State University', 'Barron Orie', 'Accounting', 5.0, 2),
#  ('Pennsylvania State University',
#   'Barry Theresa',
#   'Human Development',
#   3.2,
#   19),
#  ('Pennsylvania State University', 'Barsom Paul', 'Music', 4.9, 6),
#  ('Pennsylvania State University', 'Bartell Paul', 'Animal Science', 4.0, 3),
#  ('Pennsylvania State University', 'Barthelme Thomas', 'Mathematics', 2.1, 4),
#  ('Pennsylvania State University', 'Bartlett Bart', 'Hospitality', 3.7, 42),
#  ('Pennsylvania State University', 'Bartok Cynthia', 'Kinesiology', 2.0, 3),
#  ('Pennsylvania State University', 'Barton Russell', 'Statistics', 4.4, 5),
#  ('Pennsylvania State University', 'Barton Jennifer', 'Nursing', 4.0, 1),
#  ('Pennsylvania State University',
#   'Basak Amrita',
#   'Mechanical Engineering',
#   1.0,
#   2),
#  ('Pennsylvania State University', 'Basaric Sanja', 'Health Science', 5.0, 3),
#  ('Pennsylvania State University', 'Bascom Nick Frost', 'English', 4.2, 2),
#  ('Pennsylvania State University', 'Bastian Nathaniel', 'Engineering', 4.0, 1),
#  ('Pennsylvania State University',
#   'Basu Prasenjit',
#   'Civil Engineering',
#   4.0,
#   5),
#  ('Pennsylvania State University', 'Basu Sankha', 'Mathematics', 4.4, 15),
#  ('Pennsylvania State University',
#   'Basu Saurabh',
#   'Industrial Engineering',
#   2.0,
#   3),
#  ('Pennsylvania State University',
#   'Batakidis Panagiotis',
#   'Mathematics',
#   2.5,
#   7),
#  ('Pennsylvania State University', 'Batchelor Jordan', 'English', 3.0, 2),
#  ('Pennsylvania State University', 'Batista Juan', 'Mathematics', 3.6, 4),
#  ('Pennsylvania State University', 'Battaglia Jo', 'Mathematics', 4.7, 21),
#  ('Pennsylvania State University',
#   'Bauer Jennifer',
#   'Health Administration',
#   5.0,
#   1),
#  ('Pennsylvania State University', 'Baughman Kathy', 'Accounting', 3.5, 2),
#  ('Pennsylvania State University', 'Baukus Robert', 'Communication', 2.1, 10),
#  ('Pennsylvania State University',
#   'Baukus-Cabrerra Maria',
#   'Communication',
#   4.4,
#   4),
#  ('Pennsylvania State University', 'Baum Paul', 'Mathematics', 2.4, 57),
#  ('Pennsylvania State University', 'Bauman Joseph', 'Spanish', 4.6, 14),
#  ('Pennsylvania State University',
#   'Baumann Zachary',
#   'Political Science',
#   3.6,
#   63),
#  ('Pennsylvania State University', 'Baumgartner Johan', 'Marketing', 3.1, 4),
#  ('Pennsylvania State University', 'Baumgartner Brad', 'English', 3.3, 7),
#  ('Pennsylvania State University',
#   'Baums Illiana',
#   'Biological Sciences',
#   1.7,
#   3),
#  ('Pennsylvania State University',
#   'Baxter Kristen',
#   'Classical  Medieval Studies',
#   4.2,
#   14),
#  ('Pennsylvania State University', 'Baxter Ryan', 'Geography', 4.0, 20),
#  ('Pennsylvania State University', 'Baxter Andrew', 'Mathematics', 4.2, 50),
#  ('Pennsylvania State University', 'Bayas Kelly', 'English', 3.0, 3),
#  ('Pennsylvania State University',
#   'Baylor Ethelind',
#   'Behavioral Sciences',
#   2.5,
#   2),
#  ('Pennsylvania State University', 'Baztan Juan', 'Architecture', 5.0, 1),
#  ('Pennsylvania State University', 'Beale John', 'Journalism', 4.8, 14),
#  ('Pennsylvania State University', 'Beane Robbie', 'Mathematics', 4.6, 8),
#  ('Pennsylvania State University',
#   'Beasley Val',
#   'Veterinary Sciences',
#   4.5,
#   4),
#  ('Pennsylvania State University', 'Beaury Robert', 'Engineering', 4.5, 12),
#  ('Pennsylvania State University', 'Beaver Dan', 'History', 2.3, 43),
#  ('Pennsylvania State University',
#   'Beblo Joshua',
#   'Landscape Architecture & Regional Planning',
#   2.8,
#   2),
#  ('Pennsylvania State University',
#   'Bechtel Jon',
#   'Mechanical Engineering',
#   5.0,
#   1),
#  ('Pennsylvania State University', 'Beck Christy', 'Psychology', 5.0, 2),
#  ('Pennsylvania State University', 'Becker Robin', 'English', 3.6, 7),
#  ('Pennsylvania State University', 'Becker Christian', 'Philosophy', 3.3, 10),
#  ('Pennsylvania State University',
#   'Becker Erin',
#   'Biological Sciences',
#   5.0,
#   1),
#  ('Pennsylvania State University',
#   'Beckerman Stephen',
#   'Anthropology',
#   3.4,
#   35),
#  ('Pennsylvania State University', 'Beckett Tracy', 'English', 4.4, 5),
#  ('Pennsylvania State University', 'Beckman Matthew', 'Statistics', 4.7, 3),
#  ('Pennsylvania State University', 'Bede Dayse', 'Photography', 5.0, 2),
#  ('Pennsylvania State University', 'Bedejus Alison', 'French', 4.8, 2),
#  ('Pennsylvania State University', 'Bedell Lori', 'Communication', 3.9, 53),
#  ('Pennsylvania State University', 'Bee Beth Anne', 'Geography', 2.0, 1),
#  ('Pennsylvania State University',
#   'Beebee Thomas',
#   'Comparative Literature',
#   3.2,
#   21),
#  ('Pennsylvania State University', 'Beegle Douglas', 'Agriculture', 5.0, 1),
#  ('Pennsylvania State University',
#   'Beese Allison',
#   'Materials Engineering',
#   4.3,
#   10),
#  ('Pennsylvania State University',
#   'Beevers David',
#   'Mechanical Engineering',
#   2.0,
#   11),
#  ('Pennsylvania State University',
#   'Behoora Ishan',
#   'Computer Science',
#   3.9,
#   14),
#  ('Pennsylvania State University', 'Behun William', 'Philosophy', 4.7, 14),
#  ('Pennsylvania State University', 'Beierlein James', 'Agriculture', 3.5, 21),
#  ('Pennsylvania State University', 'Beishline Nicholas', 'English', 3.3, 10),
#  ('Pennsylvania State University', 'Belanger Jonna', 'Kinesiology', 3.4, 5),
#  ('Pennsylvania State University', 'Belden Mark', 'Kinesiology', 5.0, 6),
#  ('Pennsylvania State University',
#   'Belegundu Ashok D',
#   'Mechanical Engineering',
#   3.0,
#   15),
#  ('Pennsylvania State University', 'Belk John', 'English', 3.9, 4),
#  ('Pennsylvania State University', 'Bell Bernard', 'English', 2.3, 18),
#  ('Pennsylvania State University', 'Bell Kevin', 'English', 3.6, 12),
#  ('Pennsylvania State University', 'Bell Emily', 'Biochemistry', 5.0, 2),
#  ('Pennsylvania State University', 'Belland Brian', 'Education', 1.5, 2),
#  ('Pennsylvania State University', 'Bellinger Evelyn', 'Nursing', 5.0, 2),
#  ('Pennsylvania State University', 'Belmonte Andrew', 'Mathematics', 4.0, 9),
#  ('Pennsylvania State University', 'Beltz Roger', 'Biology', 4.8, 17),
#  ('Pennsylvania State University',
#   'Beltzer Emilie',
#   'Behavioral Sciences',
#   2.7,
#   6),
#  ('Pennsylvania State University',
#   'Belue Rhonda',
#   'Health Administration',
#   4.5,
#   4),
#  ('Pennsylvania State University',
#   'Ben-Jebria Aziz',
#   'Chemical Engineering',
#   2.9,
#   7),
#  ('Pennsylvania State University', 'Benally Timothy', 'Kinesiology', 5.0, 1),
#  ('Pennsylvania State University', 'Bender Rebecca', 'Languages', 5.0, 2),
#  ('Pennsylvania State University', 'Bendich Paul', 'Mathematics', 3.6, 9),
#  ('Pennsylvania State University', 'Benesi Alan', 'Chemistry', 2.3, 25),
#  ('Pennsylvania State University', 'Benesi Alan James', 'Chemistry', 1.0, 1),
#  ('Pennsylvania State University', 'Benitez Vincent', 'Music', 3.9, 14),
#  ('Pennsylvania State University', 'Benjamin Alan', 'Sociology', 4.5, 25),
#  ('Pennsylvania State University', 'Benkiran Amine', 'Mathematics', 4.7, 111),
#  ('Pennsylvania State University', 'Bensel Alyse', 'English', 2.0, 3),
#  ('Pennsylvania State University', 'Benson Thomas', 'Communication', 4.1, 6),
#  ('Pennsylvania State University', 'Berezniak John', 'Engineering', 4.2, 14),
#  ('Pennsylvania State University', 'Berg Adam', 'Kinesiology', 2.5, 1),
#  ('Pennsylvania State University', 'Berger Zachary', 'Engineering', 4.0, 1),
#  ('Pennsylvania State University', 'Berghage Robert', 'Agriculture', 4.2, 8),
#  ('Pennsylvania State University',
#   'Bergmaier Mike',
#   'Communication Arts',
#   3.5,
#   1),
#  ('Pennsylvania State University', 'Bergsma Theodore', 'Philosophy', 5.0, 6),
#  ('Pennsylvania State University', 'Bergstein Andrew', 'Marketing', 3.2, 73),
#  ('Pennsylvania State University', 'Bergstrom Mark', 'Sociology', 3.8, 4),
#  ('Pennsylvania State University',
#   'Berkman Michael',
#   'Political Science',
#   2.6,
#   17),
#  ('Pennsylvania State University', 'Berlyand Leonid', 'Mathematics', 2.2, 5),
#  ('Pennsylvania State University',
#   'Berman Piotr',
#   'Computer Science',
#   1.6,
#   37),
#  ('Pennsylvania State University', 'Berman Justus', 'English', 4.7, 9),
#  ('Pennsylvania State University', 'Bernal Miguel', 'Spanish', 4.4, 7),
#  ('Pennsylvania State University',
#   'Bernhard Michael',
#   'Political Science',
#   3.0,
#   58),
#  ('Pennsylvania State University', 'Berube Michael', 'English', 3.9, 30),
#  ('Pennsylvania State University',
#   'Betlyon John',
#   'Religious Studies',
#   3.8,
#   38),
#  ('Pennsylvania State University', 'Bettig Ronald', 'Communication', 3.2, 13),
#  ('Pennsylvania State University', 'Bevilacqua Philip', 'Chemistry', 4.5, 50),
#  ('Pennsylvania State University', 'Bey Sharif', 'Graphic Arts', 5.0, 2),
#  ('Pennsylvania State University', 'Beyerle Susan ', 'Engineering', 4.1, 7),
#  ('Pennsylvania State University', 'Bhagia Meher', 'Art', 3.0, 2),
#  ('Pennsylvania State University', 'Bharti Smita', 'Engineering', 3.9, 5),
#  ('Pennsylvania State University',
#   'Bharti Nita',
#   'Biological Sciences',
#   5.0,
#   2),
#  ('Pennsylvania State University',
#   'Bhat Kabekode',
#   'Computer Science',
#   2.0,
#   47),
#  ('Pennsylvania State University',
#   'Bhattacharya Sekhar',
#   'Mineral Engineering',
#   4.0,
#   1),
#  ('Pennsylvania State University', 'Bianchi Eugenio', 'Physics', 4.3, 15),
#  ('Pennsylvania State University', 'Bice David', 'Geology', 3.8, 25),
#  ('Pennsylvania State University',
#   'Bidgoli Morvareed',
#   'Information Sciences & Technology',
#   2.0,
#   6),
#  ('Pennsylvania State University', 'Bierens Herman', 'Economics', 3.2, 2),
#  ('Pennsylvania State University',
#   'Bilen Sven',
#   'Electrical Engineering',
#   4.1,
#   10),
#  ('Pennsylvania State University', 'Bilger Paul', 'Philosophy', 4.1, 30),
#  ('Pennsylvania State University', 'Bill Robert', 'Engineering', 4.8, 3),
#  ('Pennsylvania State University',
#   'Billy Gregory',
#   'Health Administration',
#   2.7,
#   7),
#  ('Pennsylvania State University', 'Bingaman Rod', 'Communication', 4.3, 18),
#  ('Pennsylvania State University',
#   'Binney James',
#   'Political Science',
#   3.6,
#   88),
#  ('Pennsylvania State University', 'Bird Barbara', 'Communication', 3.4, 9),
#  ('Pennsylvania State University', 'Bird Douglas', 'Anthropology', 2.8, 5),
#  ('Pennsylvania State University', 'Birdwell Robert', 'English', 3.3, 7),
#  ('Pennsylvania State University',
#   'Birmingham Julia',
#   'Communication Disorders',
#   4.8,
#   2),
#  ('Pennsylvania State University', 'Birnbaum Benjamin', 'Accounting', 4.2, 2),
#  ('Pennsylvania State University',
#   'Birschbach Mark',
#   'Communication',
#   3.5,
#   11),
#  ('Pennsylvania State University', 'Bischof Angela', 'Chemistry', 4.6, 10),
#  ('Pennsylvania State University',
#   'Bishop Kyle',
#   'Chemical Engineering',
#   4.2,
#   4),
#  ('Pennsylvania State University',
#   'Bissell Joanna',
#   'Human Development',
#   3.7,
#   10),
#  ('Pennsylvania State University',
#   'Bjornstad Ottar',
#   'Biological Sciences',
#   3.6,
#   4),
#  ('Pennsylvania State University',
#   'Black Brian',
#   'Hotel & Restaurant Management',
#   4.7,
#   3),
#  ('Pennsylvania State University',
#   'Black-Nembhard Harriet',
#   'Industrial Engineering',
#   2.4,
#   5),
#  ('Pennsylvania State University', 'Blackburn Angeliq', 'Chemistry', 4.0, 2),
#  ('Pennsylvania State University',
#   'Blackshear Earnest',
#   'Psychology',
#   2.1,
#   61),
#  ('Pennsylvania State University', 'Blair William', 'History', 4.3, 14),
#  ('Pennsylvania State University', 'Blair Dorothy', 'Nutrition', 2.7, 18),
#  ('Pennsylvania State University',
#   'Blair Karen',
#   'Human Development',
#   2.8,
#   16),
#  ('Pennsylvania State University',
#   'Blanca Antonio',
#   'Computer Science',
#   3.0,
#   3),
#  ('Pennsylvania State University', 'Blanchard Simon', 'Marketing', 4.5, 4),
#  ('Pennsylvania State University', 'Blanco Marilyn', 'Business', 4.0, 176),
#  ('Pennsylvania State University', 'Blanda Stephanie', 'Mathematics', 3.4, 10),
#  ('Pennsylvania State University', 'Blandford David', 'Economics', 3.4, 4),
#  ('Pennsylvania State University', 'Blandon Alysia', 'Psychology', 2.4, 7),
#  ('Pennsylvania State University', 'Blank Duane', 'Military Science', 5.0, 1),
#  ('Pennsylvania State University',
#   'Blankfield Bryan',
#   'Communication',
#   4.0,
#   7),
#  ('Pennsylvania State University',
#   'Blasko Kelly',
#   'Human Development',
#   2.5,
#   3),
#  ('Pennsylvania State University',
#   'Bliege Bird Rebecca',
#   'Anthropology',
#   1.0,
#   1),
#  ('Pennsylvania State University', 'Block Alan', 'Criminal Justice', 3.7, 8),
#  ('Pennsylvania State University',
#   'Blodgett Bridgett',
#   'Information Science',
#   3.5,
#   1),
#  ('Pennsylvania State University',
#   'Blood Gordon',
#   'Communication Disorders',
#   4.0,
#   4),
#  ('Pennsylvania State University',
#   'Blood Ingrid',
#   'Communication Disorders',
#   4.1,
#   12),
#  ('Pennsylvania State University', 'Bloom Caren', "Women's Studies", 5.0, 7),
#  ('Pennsylvania State University', 'Bloom Mia', "Women's Studies", 3.5, 2),
#  ('Pennsylvania State University',
#   'Bloom-Steidle Caren',
#   'Sociology',
#   4.8,
#   55),
#  ('Pennsylvania State University', 'Blue Margaret', 'Spanish', 4.7, 9),
#  ('Pennsylvania State University', 'Blue William', 'Spanish', 3.3, 9),
#  ('Pennsylvania State University', 'Bluemel Brody', 'Languages', 5.0, 2),
#  ('Pennsylvania State University', 'Blum Hester', 'English', 4.3, 20),
#  ('Pennsylvania State University',
#   'Blumsack Seth',
#   'Geological Engineering',
#   4.0,
#   12),
#  ('Pennsylvania State University', 'Boal Amie', 'Chemistry', 2.9, 30),
#  ('Pennsylvania State University', 'Boben Ronald', 'English', 2.1, 14),
#  ('Pennsylvania State University', 'Boccumini Kristen', 'Kinesiology', 5.0, 6),
#  ('Pennsylvania State University', 'Bock Randall', 'Design', 4.2, 6),
#  ('Pennsylvania State University', 'Bode-Lang Katie', 'English', 4.8, 17),
#  ('Pennsylvania State University', 'Bode-Lang Andrew', 'English', 4.8, 27),
#  ('Pennsylvania State University', 'Boden Josh', 'Meteorology', 3.5, 8),
#  ('Pennsylvania State University', 'Bodovski Katerina', 'Education', 2.9, 8),
#  ('Pennsylvania State University', 'Boehr David', 'Chemistry', 4.0, 25),
#  ('Pennsylvania State University',
#   'Boffemmyer Mindy',
#   "Women's Studies",
#   4.2,
#   25),
#  ('Pennsylvania State University', 'Boghossian Mirna', 'Accounting', 5.0, 1),
#  ('Pennsylvania State University', 'Bohn Rose', 'English', 2.7, 38),
#  ('Pennsylvania State University', 'Boisson Fabienne', 'English', 1.8, 6),
#  ('Pennsylvania State University', 'Boittin Jennifer', 'French', 4.1, 18),
#  ('Pennsylvania State University', 'Bojan Mary Joan', 'Science', 2.9, 5),
#  ('Pennsylvania State University', 'Bojan Mary', 'Chemistry', 2.4, 250),
#  ('Pennsylvania State University',
#   'Bojanala Nagagireesh',
#   'Biological Sciences',
#   4.0,
#   1),
#  ('Pennsylvania State University', 'Bojowald Martin', 'Physics', 3.6, 7),
#  ('Pennsylvania State University', 'Boldt Gail', 'Education', 4.2, 9),
#  ('Pennsylvania State University',
#   'Bollinger J. Martin',
#   'Chemistry',
#   4.0,
#   35),
#  ('Pennsylvania State University', 'Bollinger Joseph', 'Chemistry', 4.8, 5),
#  ('Pennsylvania State University', 'Bolton Lisa', 'Marketing', 2.7, 18),
#  ('Pennsylvania State University',
#   'Bonafini Fernanda',
#   'Mathematics',
#   3.0,
#   22),
#  ('Pennsylvania State University',
#   'Boni Maciej',
#   'Biological Sciences',
#   4.7,
#   3),
#  ('Pennsylvania State University', 'Bonin Ashley', 'English', 5.0, 1),
#  ('Pennsylvania State University', 'Bonner Alison', 'Mathematics', 3.0, 1),
#  ('Pennsylvania State University',
#   'Booker Squire',
#   'Biological Sciences',
#   4.0,
#   29),
#  ('Pennsylvania State University', 'Booth Joshua', 'Computer Science', 3.4, 3),
#  ('Pennsylvania State University',
#   'Booth Kayla',
#   'Information Sciences  Technology',
#   4.0,
#   2),
#  ('Pennsylvania State University', 'Boothby Thomas', 'Engineering', 2.7, 21),
#  ('Pennsylvania State University', 'Booz Patrick', 'History', 3.5, 13),
#  ('Pennsylvania State University', 'Bopp Chris', 'Kinesiology', 4.4, 10),
#  ('Pennsylvania State University', 'Bordi Pete', 'Hospitality', 4.8, 13),
#  ('Pennsylvania State University',
#   'Bores Martinez Monserrat',
#   'Spanish',
#   4.0,
#   7),
#  ('Pennsylvania State University',
#   'Borge Marcela',
#   'Information Science',
#   4.6,
#   4),
#  ('Pennsylvania State University',
#   'Borhan Ali',
#   'Chemical Engineering',
#   4.0,
#   12),
#  ('Pennsylvania State University',
#   'Borisov Alexander',
#   'Mathematics',
#   3.3,
#   40),
#  ('Pennsylvania State University', 'Borkowska Alison', 'Nutrition', 3.5, 19),
#  ('Pennsylvania State University', 'Borlu Yetkin', 'Sociology', 2.7, 3),
#  ('Pennsylvania State University',
#   'Bortiatynski Jacqueline',
#   'Chemistry',
#   2.1,
#   7),
#  ('Pennsylvania State University', 'Bortree Denise', 'Communication', 3.9, 4),
#  ('Pennsylvania State University', 'Borys Alex', 'Agriculture', 4.8, 3),
#  ('Pennsylvania State University',
#   'Bose Nirmal',
#   'Electrical Engineering',
#   2.8,
#   5),
#  ('Pennsylvania State University',
#   'Bose Mallika',
#   'Landscape Architecture & Regional Planning',
#   2.3,
#   19),
#  ('Pennsylvania State University', 'Botero Chris', 'Spanish', 4.6, 16),
#  ('Pennsylvania State University', 'Bott Alicia', 'Humanities', 4.0, 2),
#  ('Pennsylvania State University', 'Boujaoude Rita', 'French', 4.8, 6),
#  ('Pennsylvania State University', 'Bouley Brad', 'History', 4.5, 2),
#  ('Pennsylvania State University',
#   'Bounatirou Riadh',
#   'Comparative Literature',
#   4.2,
#   14),
#  ('Pennsylvania State University', 'Bourne Claire', 'Literature', 4.3, 3),
#  ('Pennsylvania State University', 'Bousquet Arthur', 'Mathematics', 4.0, 3),
#  ('Pennsylvania State University',
#   'Boven Larry ',
#   'Information Sciences  Technology',
#   4.6,
#   54),
#  ('Pennsylvania State University', 'Bowen Cathy', 'Not Specified', 3.5, 3),
#  ('Pennsylvania State University', 'Bowers Paul', 'Engineering', 3.8, 15),
#  ('Pennsylvania State University', 'Bowers Stephanie', 'Spanish', 5.0, 5),
#  ('Pennsylvania State University',
#   'Bowker Adam',
#   'Communication Disorders',
#   3.5,
#   3),
#  ('Pennsylvania State University', 'Bowlby Emily', 'Communication', 4.0, 4),
#  ('Pennsylvania State University', 'Bowley Kevin', 'Meteorology', 4.6, 9),
#  ('Pennsylvania State University', 'Bowman Caitlin', 'Psychology', 2.3, 3),
#  ('Pennsylvania State University', 'Bowman John', 'Visual Arts', 4.3, 8),
#  ('Pennsylvania State University', 'Bowman Brady', 'Philosophy', 4.4, 8),
#  ('Pennsylvania State University', 'Bowns Caru', 'Architecture', 2.2, 8),
#  ('Pennsylvania State University', 'Boyer Philip', 'Engineering', 4.6, 13),
#  ('Pennsylvania State University',
#   'Boyle Michael',
#   'Communication Disorders',
#   4.0,
#   5),
#  ('Pennsylvania State University', 'Boyle Austin', 'Economics', 2.6, 277),
#  ('Pennsylvania State University', 'Bracken Susan', 'Education', 3.2, 5),
#  ('Pennsylvania State University',
#   'Braddock Kurt',
#   'Communication Arts',
#   4.3,
#   5),
#  ('Pennsylvania State University',
#   'Brady Elizabeth',
#   'Communication',
#   4.5,
#   19),
#  ('Pennsylvania State University',
#   'Bralower Timothy',
#   'Earth Science',
#   3.7,
#   29),
#  ('Pennsylvania State University',
#   'Bramesfeld Goetz',
#   'Aerospace Engineering',
#   4.0,
#   2),
#  ('Pennsylvania State University',
#   'Brandsema Matthew',
#   'Electrical Engineering',
#   2.0,
#   1),
#  ('Pennsylvania State University', 'Brandt Robin', 'Agriculture', 4.8, 3),
#  ('Pennsylvania State University', 'Brandt Ursula', 'German', 4.5, 2),
#  ('Pennsylvania State University', 'Brandt Niel', 'Astronomy', 3.8, 17),
#  ('Pennsylvania State University', 'Brannick James', 'Mathematics', 4.5, 12),
#  ('Pennsylvania State University', 'Brannick Gina', 'Economics', 3.0, 3),
#  ('Pennsylvania State University',
#   'Branstetter Steve',
#   'Health Science',
#   4.8,
#   9),
#  ('Pennsylvania State University',
#   'Branstetter Terry',
#   'Information Sciences & Technology',
#   2.0,
#   1),
#  ('Pennsylvania State University', 'Brantley Susan', 'Geology', 2.5, 2),
#  ('Pennsylvania State University', 'Brasfield James', 'English', 4.0, 29),
#  ('Pennsylvania State University',
#   'Brasseur James',
#   'Mechanical Engineering',
#   2.8,
#   36),
#  ('Pennsylvania State University', 'Brauer John', 'Economics', 3.0, 1),
#  ('Pennsylvania State University',
#   'Breakall James',
#   'Electrical Engineering',
#   5.0,
#   4),
#  ('Pennsylvania State University', 'Breckenridge Sarah', 'English', 4.9, 4),
#  ('Pennsylvania State University', 'Bregar Mark', 'Mathematics', 4.5, 11),
#  ('Pennsylvania State University',
#   'Brendese Philip',
#   'Political Science',
#   4.2,
#   8),
#  ('Pennsylvania State University',
#   'Brenizer Jack',
#   'Mechanical Engineering',
#   4.4,
#   4),
#  ('Pennsylvania State University', 'Brennan Mark', 'Agriculture', 4.7, 6),
#  ('Pennsylvania State University', 'Brennan Erin', 'Business', 5.0, 2),
#  ('Pennsylvania State University',
#   'Brennan Sean',
#   'Mechanical Engineering',
#   4.5,
#   21),
#  ('Pennsylvania State University', 'Brent Daniel', 'Agriculture', 1.8, 5),
#  ('Pennsylvania State University',
#   'Brentner Kenneth',
#   'Aerospace Engineering',
#   3.0,
#   2),
#  ('Pennsylvania State University', 'Brewer Cynthia', 'Geography', 4.3, 12),
#  ('Pennsylvania State University', 'Briand Cedric', 'French', 4.5, 1),
#  ('Pennsylvania State University', 'Briceno Mia', 'Communication', 3.1, 18),
#  ('Pennsylvania State University', 'Bridger J.', 'Agriculture', 1.5, 2),
#  ('Pennsylvania State University', 'Bridges Copeland Katrice', 'Law', 2.0, 1),
#  ('Pennsylvania State University', 'Briggs R.J.', 'Economics', 2.9, 7),
#  ('Pennsylvania State University', 'Bright K.D.', 'English', 4.4, 21),
#  ('Pennsylvania State University', 'Bright David', 'Social Work', 5.0, 1),
#  ('Pennsylvania State University', 'Brill Kenneth', 'Art', 4.0, 1),
#  ('Pennsylvania State University', 'Brindley Erica', 'History', 3.8, 24),
#  ('Pennsylvania State University', 'Brinkmann Tobias', 'History', 4.6, 11),
#  ('Pennsylvania State University', 'Brinton Anne', 'History', 2.5, 2),
#  ('Pennsylvania State University', 'Briscoe Forrest', 'Sociology', 3.1, 15),
#  ('Pennsylvania State University',
#   'Brisini Travis',
#   'Communication Arts',
#   4.7,
#   14),
#  ('Pennsylvania State University', 'Brisini Kellie', 'Communication', 5.0, 5),
#  ('Pennsylvania State University', 'Britton Jeanne', 'English', 4.7, 6),
#  ('Pennsylvania State University', 'Brizzi Brunella', 'Italian', 4.2, 11),
#  ('Pennsylvania State University', 'Broadnax Steven', 'Theater', 3.1, 7),
#  ('Pennsylvania State University', 'Brock Theresa', 'French', 5.0, 3),
#  ('Pennsylvania State University',
#   'Brocker Donovan',
#   'Electrical Engineering',
#   4.5,
#   1),
#  ('Pennsylvania State University', 'Brockopp Jonathan', 'Theology', 3.5, 32),
#  ('Pennsylvania State University', 'Brodie Monique', 'English', 1.2, 12),
#  ('Pennsylvania State University', 'Broka Damien', 'Mathematics', 5.0, 1),
#  ('Pennsylvania State University', 'Brooks Robert', 'Geography', 3.9, 16),
#  ('Pennsylvania State University', 'Brooks Debbie', 'Education', 4.7, 16),
#  ('Pennsylvania State University', 'Brooks Lauren', 'German', 4.8, 9),
#  ('Pennsylvania State University', 'Brooks Jason', 'Humanities', 4.1, 27),
#  ('Pennsylvania State University', 'Brounce Maryjo', 'Geology', 3.2, 3),
#  ('Pennsylvania State University',
#   'Broussard Gregory',
#   'Biological Sciences',
#   4.6,
#   5),
#  ('Pennsylvania State University',
#   'Broussard Gregory',
#   'Biochemistry',
#   5.0,
#   5),
#  ('Pennsylvania State University', 'Brower Margaret', 'Management', 2.0, 22),
#  ('Pennsylvania State University', 'Brown Frederick', 'Psychology', 3.0, 64),
#  ('Pennsylvania State University', 'Brown Nate', 'Mathematics', 4.4, 20),
#  ('Pennsylvania State University', 'Brown Josh', 'German', 4.8, 22),
#  ('Pennsylvania State University', 'Brown Donald', 'Not Specified', 4.0, 3),
#  ('Pennsylvania State University', 'Brown Aaron', 'Mathematics', 4.8, 2),
#  ('Pennsylvania State University', 'Brown Laura', 'English', 5.0, 2),
#  ('Pennsylvania State University', 'Brown Marcus', 'Military Science', 5.0, 1),
#  ('Pennsylvania State University', 'Brown Jaime', 'Economics', 4.3, 19),
#  ('Pennsylvania State University', 'Brown Justin', 'Animal Science', 5.0, 4),
#  ('Pennsylvania State University', 'Brown David', 'Economics', 4.5, 223),
#  ('Pennsylvania State University',
#   'Brownawell Woodrow',
#   'Mathematics',
#   3.5,
#   17),
#  ('Pennsylvania State University', 'Browne Kevin', 'English', 3.8, 14),
#  ('Pennsylvania State University', 'Browne Stephen', 'Communication', 4.6, 12),
#  ('Pennsylvania State University', 'Browne Sarah', 'Mathematics', 2.2, 11),
#  ('Pennsylvania State University',
#   'Brownson Jeffrey',
#   'Mineral Engineering',
#   3.9,
#   21),
#  ('Pennsylvania State University', 'Bruening Thomas', 'Agriculture', 3.2, 9),
#  ('Pennsylvania State University', 'Bruhn Henning', 'Art History', 4.7, 3),
#  ('Pennsylvania State University', 'Bruhn Heather', 'Art History', 4.3, 6),
#  ('Pennsylvania State University', 'Brune William', 'Meteorology', 3.1, 15),
#  ('Pennsylvania State University',
#   'Brungart Timothy',
#   'Aerospace Engineering',
#   4.1,
#   4),
#  ('Pennsylvania State University', 'Bruno Teresa', 'Philosophy', 5.0, 2),
#  ('Pennsylvania State University', 'Brunow Beate', 'German', 4.6, 7),
#  ('Pennsylvania State University', 'Bruns Maryann', 'Agriculture', 3.0, 3),
#  ('Pennsylvania State University', 'Brunson Julie', 'Psychology', 1.9, 10),
#  ('Pennsylvania State University', 'Brusseler Melanie', 'English', 3.0, 1),
#  ('Pennsylvania State University', 'Brust Imke', 'German', 4.8, 16),
#  ('Pennsylvania State University',
#   'Bryant Donald',
#   'Biological Sciences',
#   2.0,
#   6),
#  ('Pennsylvania State University',
#   'Brzencheck Alison',
#   'Communication Arts',
#   2.8,
#   11),
#  ('Pennsylvania State University', 'Brzycki Henry', 'Education', 5.0, 6),
#  ('Pennsylvania State University',
#   'Buanafina Marcia',
#   'Biological Sciences',
#   4.0,
#   9),
#  ('Pennsylvania State University', 'Bubar Mallory', 'Humanities', 4.3, 3),
#  ('Pennsylvania State University', 'Bubash Connie', 'English', 3.8, 8),
#  ('Pennsylvania State University',
#   'Bucciarelli Nicholas Nick',
#   'Information Sciences amp Technology',
#   1.3,
#   10),
#  ('Pennsylvania State University',
#   'Buchanan Patricia',
#   'Mathematics',
#   2.7,
#   157),
#  ('Pennsylvania State University',
#   'Buchannan Patricia',
#   'Statistics',
#   2.8,
#   34),
#  ('Pennsylvania State University', 'Bucior Christine', 'Sociology', 1.0, 6),
#  ('Pennsylvania State University',
#   'Buckland Peter',
#   'University Community',
#   5.0,
#   1),
#  ('Pennsylvania State University', 'Buckley William', 'Kinesiology', 3.6, 13),
#  ('Pennsylvania State University', 'Buckmiller Rebecca', 'Spanish', 4.5, 4),
#  ('Pennsylvania State University',
#   'Buehler Emily',
#   'Communication Arts',
#   5.0,
#   3),
#  ('Pennsylvania State University', 'Bueter Joe', 'English', 4.5, 2),
#  ('Pennsylvania State University', 'Bueter Joseph', 'English', 4.0, 2),
#  ('Pennsylvania State University', 'Buffington Dennis', 'Engineering', 5.0, 3),
#  ('Pennsylvania State University',
#   'Bulathsinhala Priyangi',
#   'Statistics',
#   4.2,
#   12),
#  ('Pennsylvania State University', 'Bumbaugh Alyssa', 'Agriculture', 2.0, 1),
#  ('Pennsylvania State University', 'Bundro Richard Joseph', 'Finance', 3.7, 3),
#  ('Pennsylvania State University', 'Bundro Richard', 'Finance', 4.0, 19),
#  ('Pennsylvania State University', 'Bundy O. Richard', 'Music', 4.8, 30),
#  ('Pennsylvania State University', 'Bunnell Dean', 'Management', 4.1, 5),
#  ('Pennsylvania State University', 'Burago Dmitri', 'Mathematics', 2.7, 17),
#  ('Pennsylvania State University',
#   'Burger Brea',
#   'Behavioral Sciences',
#   3.0,
#   8),
#  ('Pennsylvania State University',
#   'Burgess Robert',
#   'Human Development',
#   3.4,
#   12),
#  ('Pennsylvania State University',
#   'Burgos William',
#   'Environmental Engineering',
#   3.1,
#   6),
# ...
#  ('Pennsylvania State University', 'Clark Justin', 'History', 4.2, 5),
#  ('Pennsylvania State University',
#   'Clark Paul',
#   'Labor & Employment Relations',
#   4.0,
#   38),
#  ('Pennsylvania State University', 'Clark  Ashley', 'Nursing', 4.3, 3),
#  ('Pennsylvania State University', 'Clark-Evans Chris', 'French', 2.2, 12),
#  ('Pennsylvania State University', 'Claudius Sascha', 'Economics', 3.3, 7),
#  ('Pennsylvania State University', 'Clem Cynthia', 'English', 3.4, 15),
#  ('Pennsylvania State University', 'Clemente Frank', 'Sociology', 4.8, 193),
#  ('Pennsylvania State University', 'Clemente Laurena', 'English', 2.1, 10),
#  ('Pennsylvania State University', 'Clements Ann', 'Music', 3.2, 4),
#  ('Pennsylvania State University',
#   'Cleveland Jeanette',
#   'Psychology',
#   4.2,
#   14),
#  ('Pennsylvania State University',
#   'Cleveland Hobart',
#   'Human Development',
#   3.5,
#   27),
#  ('Pennsylvania State University', 'Cleveland John', 'Mathematics', 2.6, 25),
#  ('Pennsylvania State University', 'Cliette Brian', 'Hospitality', 4.0, 13),
#  ('Pennsylvania State University', 'Clifford Norman', 'Economics', 3.9, 65),
#  ('Pennsylvania State University',
#   'Clifford Caroline',
#   'Environmental Engineering',
#   3.4,
#   4),
#  ('Pennsylvania State University', 'Climenhaga Vaughn', 'Mathematics', 3.2, 6),
#  ('Pennsylvania State University', 'Clothiaux Eugene', 'Meteorology', 4.7, 11),
#  ('Pennsylvania State University', 'Clough Zach', 'English', 3.8, 15),
#  ('Pennsylvania State University', 'Coangelo Gus', 'Management', 3.5, 5),
#  ('Pennsylvania State University', 'Cobb William', 'English', 3.8, 8),
#  ('Pennsylvania State University', 'Cochran Jennifer', 'Art History', 3.7, 9),
#  ('Pennsylvania State University', 'Coduti Wendy', 'Education', 1.9, 3),
#  ('Pennsylvania State University', 'Cody Adam', 'Communication', 3.8, 6),
#  ('Pennsylvania State University', 'Cody Thomas', 'Music', 4.6, 24),
#  ('Pennsylvania State University', 'Coelho Chase', 'Psychology', 2.5, 1),
#  ('Pennsylvania State University', 'Cohen Jeffery', 'Anthropology', 2.9, 13),
#  ('Pennsylvania State University', 'Cohen Rajal', 'Psychology', 2.9, 13),
#  ('Pennsylvania State University', 'Colangelo Augustus', 'Business', 4.2, 117),
#  ('Pennsylvania State University',
#   'Colapietro Vincent',
#   'Philosophy',
#   4.1,
#   18),
#  ('Pennsylvania State University',
#   'Colby Ralph',
#   'Materials Engineering',
#   3.5,
#   1),
#  ('Pennsylvania State University', 'Colby Scott', 'Agriculture', 4.0, 1),
#  ('Pennsylvania State University', 'Cole Milton', 'Physics', 2.0, 11),
#  ('Pennsylvania State University',
#   'Cole Andy',
#   'Landscape Architecture & Regional Planning',
#   4.5,
#   3),
#  ('Pennsylvania State University', 'Cole Pamela', 'Psychology', 5.0, 1),
#  ('Pennsylvania State University', 'Cole Pamela', 'Latin', 3.2, 30),
#  ('Pennsylvania State University', 'Colebrook Claire', 'English', 4.5, 12),
#  ('Pennsylvania State University', 'Coledge Tom', 'Engineering', 3.5, 2),
#  ('Pennsylvania State University', 'Coleman Mary Dean', 'Nutrition', 3.0, 34),
#  ('Pennsylvania State University',
#   'Coleman Sulamunn',
#   'Behavioral Sciences',
#   4.2,
#   4),
#  ('Pennsylvania State University', 'Coles Gregory', 'English', 5.0, 1),
#  ('Pennsylvania State University',
#   'Coletta Kristin',
#   'Communication Arts',
#   4.2,
#   4),
#  ('Pennsylvania State University', 'Coletu Ebony', 'English', 4.0, 3),
#  ('Pennsylvania State University', 'Colins Morris', 'English', 2.2, 2),
#  ('Pennsylvania State University', 'Coll Michael', 'Kinesiology', 4.8, 3),
#  ('Pennsylvania State University', 'Coll Katherine', 'Economics', 3.2, 99),
#  ('Pennsylvania State University', 'Colledge Thomas', 'Engineering', 3.6, 66),
#  ('Pennsylvania State University', 'Collins Morris', 'English', 4.6, 14),
#  ('Pennsylvania State University', 'Collins Peter', 'English', 4.4, 8),
#  ('Pennsylvania State University',
#   'Collins Robert',
#   'Computer Science',
#   4.7,
#   9),
#  ('Pennsylvania State University', 'Collins Scott', 'Accounting', 4.1, 52),
#  ('Pennsylvania State University', 'Collopy Alex', 'Education', 4.6, 5),
#  ('Pennsylvania State University', 'Collura Bonnie', 'Visual Arts', 4.4, 6),
#  ('Pennsylvania State University', 'Comstock Thomas', 'Business', 3.3, 10),
#  ('Pennsylvania State University',
#   'Conejo-Lopez Griselda',
#   'Computer Science',
#   3.5,
#   23),
#  ('Pennsylvania State University', 'Conklin Carla', 'English', 4.3, 11),
#  ('Pennsylvania State University',
#   'Conlan Kathleen',
#   'Labor  Employment Relations',
#   3.2,
#   5),
#  ('Pennsylvania State University',
#   'Conlon Stephen',
#   'Aerospace Engineering',
#   3.8,
#   2),
#  ('Pennsylvania State University',
#   'Connelly Jones Maureen',
#   'Nursing',
#   3.4,
#   5),
#  ('Pennsylvania State University',
#   'Connolly-Ahern Colleen',
#   'Communication',
#   2.1,
#   19),
#  ('Pennsylvania State University', 'Conrad Scott', 'Mathematics', 4.9, 7),
#  ('Pennsylvania State University', 'Conroy Dave', 'Psychology', 3.3, 18),
#  ('Pennsylvania State University', 'Considine Tim', 'Earth Science', 1.9, 8),
#  ('Pennsylvania State University', 'Constantino Daniel', 'Physics', 3.0, 26),
#  ('Pennsylvania State University',
#   'Constantinou Panayiotis',
#   'Statistics',
#   3.7,
#   3),
#  ('Pennsylvania State University', 'Conway Daniel', 'Philosophy', 3.9, 14),
#  ('Pennsylvania State University', 'Conway Jessica', 'Mathematics', 3.4, 6),
#  ('Pennsylvania State University', 'Conyers Liza', 'Education', 3.8, 3),
#  ('Pennsylvania State University',
#   'Cooduvalli Shashikant',
#   'Animal Science',
#   1.0,
#   2),
#  ('Pennsylvania State University', 'Cook Christina', 'English', 5.0, 1),
#  ('Pennsylvania State University', 'Cooke Tanner', 'Communication', 3.9, 3),
#  ('Pennsylvania State University',
#   'Cooper Victor',
#   'Criminal Justice',
#   2.2,
#   6),
#  ('Pennsylvania State University', 'Cooper Kim', 'Hospitality', 5.0, 1),
#  ('Pennsylvania State University', 'Cooper James', 'Architecture', 3.9, 11),
#  ('Pennsylvania State University', 'Coraor Lee', 'Computer Science', 4.6, 24),
#  ('Pennsylvania State University',
#   'Corigliano Alessandra',
#   'Italian',
#   3.6,
#   15),
#  ('Pennsylvania State University',
#   'Corkery Shannon',
#   'Human Development',
#   4.3,
#   3),
#  ('Pennsylvania State University', 'Cornaggia Kimberly', 'Finance', 2.7, 3),
#  ('Pennsylvania State University', 'Cornaggia Jess', 'Finance', 3.8, 8),
#  ('Pennsylvania State University',
#   'Corneal Sherry',
#   'Human Development',
#   4.4,
#   117),
#  ('Pennsylvania State University', 'Corneal David', 'Business', 2.7, 49),
#  ('Pennsylvania State University', 'Cornell Carl', 'French', 5.0, 3),
#  ('Pennsylvania State University', 'Cornette Carla', 'Italian', 5.0, 4),
#  ('Pennsylvania State University', 'Cornwall Robert', 'Business', 4.0, 5),
#  ('Pennsylvania State University', 'Corr Anne', 'Nutrition', 4.5, 5),
#  ('Pennsylvania State University',
#   'Corrado Alfred',
#   'Communication Disorders',
#   4.6,
#   7),
#  ('Pennsylvania State University', 'Corrado Alfred', 'Languages', 4.5, 1),
#  ('Pennsylvania State University',
#   'Correa Jonathan',
#   'Comparative Literature',
#   4.6,
#   9),
#  ('Pennsylvania State University',
#   'Correia-Matias Joao',
#   'Mathematics',
#   3.5,
#   2),
#  ('Pennsylvania State University', 'Correll John', 'Engineering', 1.6, 9),
#  ('Pennsylvania State University', 'Corwin Rebecca', 'Health Science', 4.6, 4),
#  ('Pennsylvania State University', 'costa robyn', 'Music', 3.3, 3),
#  ('Pennsylvania State University', 'Costantino Daniel', 'Physics', 3.7, 70),
#  ('Pennsylvania State University',
#   'Costanzo Francesco',
#   'Engineering',
#   4.3,
#   22),
#  ('Pennsylvania State University', 'Costanzo Denise', 'Art History', 3.9, 18),
#  ('Pennsylvania State University',
#   'Costello Megan',
#   'Information Sciences  Technology',
#   3.0,
#   25),
#  ('Pennsylvania State University', 'Cotner Carl', 'Mathematics', 3.5, 23),
#  ('Pennsylvania State University', 'Cotruvo Joseph', 'Chemistry', 3.4, 11),
#  ('Pennsylvania State University', 'Cottart Simon', 'French', 4.8, 11),
#  ('Pennsylvania State University',
#   'Coughlin Dan',
#   'Information Sciences  Technology',
#   4.3,
#   3),
#  ('Pennsylvania State University', 'Coulson N. Edward', 'Economics', 3.0, 1),
#  ('Pennsylvania State University', 'Coulson Ed', 'Economics', 3.7, 14),
#  ('Pennsylvania State University',
#   'Countermine Molly',
#   'Human Development',
#   4.5,
#   179),
#  ('Pennsylvania State University', 'Coupland John', 'Food Science', 4.0, 1),
#  ('Pennsylvania State University', 'Coutu Stephane', 'Physics', 3.4, 66),
#  ('Pennsylvania State University', 'Cowan Melissa', 'English', 3.5, 6),
#  ('Pennsylvania State University',
#   'Cowan Tiana',
#   'Communication Disorders',
#   4.0,
#   1),
#  ('Pennsylvania State University', 'Cowen Douglas', 'Physics', 3.0, 27),
#  ('Pennsylvania State University', 'Cox Jeremy', 'Communication Arts', 4.3, 6),
#  ('Pennsylvania State University', 'Cox Graham', 'Mathematics', 3.2, 5),
#  ('Pennsylvania State University',
#   'Cox Charles',
#   'Engineering Science amp Mechanics',
#   4.0,
#   1),
#  ('Pennsylvania State University', 'Cox Charles', 'Engineering', 3.2, 17),
#  ('Pennsylvania State University', 'Coy Jeffrey', 'Finance', 3.0, 2),
#  ('Pennsylvania State University', 'Craig Curtis', 'Theater', 4.8, 4),
#  ('Pennsylvania State University', 'Craig Nathan', 'Anthropology', 5.0, 2),
#  ('Pennsylvania State University',
#   'Craighead Christopher',
#   'Business',
#   4.9,
#   9),
#  ('Pennsylvania State University', 'Cramer Ben', 'Communication', 4.4, 11),
#  ('Pennsylvania State University',
#   'Cramer Donald',
#   'Labor  Employment Relations',
#   5.0,
#   1),
#  ('Pennsylvania State University', 'Cranage David', 'Hospitality', 3.8, 3),
#  ('Pennsylvania State University', 'Crane Robert', 'Geology', 2.8, 17),
#  ('Pennsylvania State University',
#   'Crassweller Robert',
#   'Horticulture',
#   2.5,
#   1),
#  ('Pennsylvania State University', 'Cremer Paul', 'Chemistry', 3.6, 13),
#  ('Pennsylvania State University', 'Cremona Marzia', 'Statistics', 3.6, 28),
#  ('Pennsylvania State University', 'Crespi Vincent', 'Physics', 2.5, 75),
#  ('Pennsylvania State University',
#   'Creuz Judith Ann',
#   'Communication Disorders',
#   4.6,
#   8),
#  ('Pennsylvania State University', 'Crisp Tyrone', 'Mathematics', 4.3, 22),
#  ('Pennsylvania State University', 'Criss Marika', 'Literature', 4.8, 5),
#  ('Pennsylvania State University',
#   'Crissman-Ishler Jennifer',
#   'Education',
#   4.3,
#   41),
#  ('Pennsylvania State University',
#   'Crittenden Crista',
#   'Behavioral Sciences',
#   4.8,
#   48),
#  ('Pennsylvania State University', 'Croft Ryan', 'English', 3.1, 12),
#  ('Pennsylvania State University', 'Croome Sarah', 'Mathematics', 3.7, 6),
#  ('Pennsylvania State University',
#   'Crosby Brian',
#   'Human Development',
#   4.3,
#   81),
#  ('Pennsylvania State University', 'Cross Gary', 'History', 3.3, 21),
#  ('Pennsylvania State University', 'Crowe Elizabeth', 'Chemistry', 4.3, 9),
#  ('Pennsylvania State University', 'Crum Robert', 'Accounting', 2.8, 22),
#  ('Pennsylvania State University', 'Cruz Ariane', "Women's Studies", 4.9, 7),
#  ('Pennsylvania State University', 'Cruz Arianne', "Women's Studies", 4.0, 1),
#  ('Pennsylvania State University', 'Cruz Martinez Juliana', 'Spanish', 4.0, 1),
#  ('Pennsylvania State University', 'Cuervo-Hewitt Julia', 'Spanish', 4.8, 4),
#  ('Pennsylvania State University', 'Cui Jian', 'Communication', 2.0, 1),
#  ('Pennsylvania State University', 'Cui Shijie', 'Statistics', 1.0, 1),
#  ('Pennsylvania State University', 'Culotta Carmen', 'Psychology', 3.2, 5),
#  ('Pennsylvania State University', 'Cummings Keith', 'Fine Arts', 3.9, 18),
#  ('Pennsylvania State University', 'Cummins Terry', 'Business', 3.7, 3),
#  ('Pennsylvania State University',
#   'Cundiff Kelsey',
#   'Criminal Justice',
#   2.5,
#   2),
#  ('Pennsylvania State University', 'Cuomo Dana', 'Geography', 5.0, 3),
#  ('Pennsylvania State University', 'Curling Michelle', 'Accounting', 3.3, 21),
#  ('Pennsylvania State University', 'Curran Brian', 'Art History', 3.5, 30),
#  ('Pennsylvania State University',
#   'Curtis Wayne',
#   'Chemical Engineering',
#   3.0,
#   23),
#  ('Pennsylvania State University', 'Cushenbery Lily', 'Psychology', 2.7, 3),
#  ('Pennsylvania State University', 'Cushing Nancy', 'English', 3.0, 3),
#  ('Pennsylvania State University',
#   'Cusumano Joseph',
#   'Engineering, Science, & Mechanics',
#   3.9,
#   20),
#  ('Pennsylvania State University', 'Cutezo Beth', 'Nursing', 3.1, 10),
#  ('Pennsylvania State University', 'Cutter Catherine', 'Agriculture', 5.0, 1),
#  ('Pennsylvania State University', 'Cuya Lorena', 'Spanish', 4.2, 15),
#  ('Pennsylvania State University',
#   'Cyr Richard',
#   'Biological Sciences',
#   3.2,
#   45),
#  ('Pennsylvania State University', 'Cyr Van', 'Mathematics', 3.5, 9),
#  ('Pennsylvania State University',
#   'Czymoniewicz Klipp',
#   "Women's Studies",
#   5.0,
#   1),
#  ('Pennsylvania State University',
#   "D'Andrea Francesco",
#   'Mathematics',
#   3.0,
#   1),
#  ('Pennsylvania State University',
#   "D'Augelli Anthony",
#   'Human Development',
#   3.9,
#   17),
#  ('Pennsylvania State University',
#   'Dabo Ismaila',
#   'Materials Engineering',
#   4.8,
#   6),
#  ('Pennsylvania State University', 'Daenzer Calder', 'Mathematics', 4.7, 3),
#  ('Pennsylvania State University', 'Daise David', 'Philosophy', 1.0, 3),
#  ('Pennsylvania State University',
#   'Daley Christina',
#   'Select department',
#   4.9,
#   22),
#  ('Pennsylvania State University', 'Dalola Amanda', 'French', 4.9, 20),
#  ('Pennsylvania State University',
#   'Damaske Sarah',
#   'Labor & Employment Relations',
#   4.7,
#   5),
#  ('Pennsylvania State University', 'Danahy Anne', 'Communication', 3.8, 9),
#  ('Pennsylvania State University',
#   'Dann Michael',
#   'Biological Sciences',
#   4.6,
#   59),
#  ('Pennsylvania State University', 'Dansky Kathryn', 'Health Science', 3.4, 7),
#  ('Pennsylvania State University',
#   'Dansky Larry',
#   'Health Administration',
#   4.4,
#   15),
#  ('Pennsylvania State University', 'Danube Cinnamon', 'Psychology', 3.3, 7),
#  ('Pennsylvania State University', 'Darby Megan', 'English', 2.8, 2),
#  ('Pennsylvania State University', 'Dardis Frank', 'Communication', 4.0, 33),
#  ('Pennsylvania State University', 'Darnell Jamey', 'Management', 3.8, 5),
#  ('Pennsylvania State University', 'Darragjati Julian', 'English', 4.1, 15),
#  ('Pennsylvania State University', 'Darrah Adrienne', 'Business', 4.5, 2),
#  ('Pennsylvania State University',
#   'Das Chitaranjan',
#   'Computer Science',
#   2.8,
#   12),
#  ('Pennsylvania State University', 'Das Anirban', 'Mathematics', 1.5, 4),
#  ('Pennsylvania State University',
#   'Datta Anjuli',
#   'Biological Sciences',
#   3.8,
#   15),
#  ('Pennsylvania State University',
#   'Dattilo John',
#   'Recreation, Parks, & Tourism',
#   3.1,
#   9),
#  ('Pennsylvania State University',
#   'Daughtry John',
#   'Information Science',
#   4.9,
#   4),
#  ('Pennsylvania State University', 'Davidson Maritza', 'Spanish', 3.9, 12),
#  ('Pennsylvania State University',
#   'Davis Kristopher Allen',
#   'Spanish',
#   4.4,
#   11),
#  ('Pennsylvania State University', 'Davis Dennis', 'Communication', 3.2, 3),
#  ('Pennsylvania State University', 'Davis Kelly', 'Human Development', 5.0, 2),
#  ('Pennsylvania State University',
#   'Davis Matthew',
#   'Computer Science',
#   3.9,
#   10),
#  ('Pennsylvania State University', 'Davis Geffrey Mic', 'English', 4.7, 3),
#  ('Pennsylvania State University', 'Davis Ken', 'Meteorology', 4.0, 2),
#  ('Pennsylvania State University', 'Davis Vaughn', 'Theater', 4.0, 1),
#  ('Pennsylvania State University',
#   'Davis Amira',
#   'African-American Studies',
#   4.0,
#   1),
#  ('Pennsylvania State University', 'Davis Brian', 'Finance', 4.2, 25),
#  ('Pennsylvania State University', 'Daw Jonathan', 'Sociology', 2.8, 2),
#  ('Pennsylvania State University', 'Dawood Khytam', 'Psychology', 3.9, 30),
#  ('Pennsylvania State University', 'Dawson Mike', 'Communication', 4.3, 12),
#  ('Pennsylvania State University', 'Dawson Rebekah', 'Astronomy', 4.0, 3),
#  ('Pennsylvania State University',
#   'Dawson Maria',
#   'Health Administration',
#   3.0,
#   22),
#  ('Pennsylvania State University', 'Dayanada Vanitha', 'Sociology', 2.9, 15),
#  ('Pennsylvania State University',
#   'Dayananda Vanitha',
#   'Social Science',
#   3.4,
#   61),
#  ('Pennsylvania State University',
#   'Dayrat Benoit',
#   'Biological Sciences',
#   4.5,
#   2),
#  ...]

# %% [markdown]
# # DateFrame Creation

# %%
df=pd.DataFrame(prof_list)

# %%
df=df.rename(columns={0: "School", 1: "Professor", 2: "Department", 3:"Rating", 4:"Rating Count"})

# %%
df.to_csv('RateMyProfessor_Data.csv')

# %%
pd.set_option('display.max_rows', 1000)

# %%
df
# Out:
#                              School          Professor         Department  \
# 0     Pennsylvania State University    Aalberts Robert                Law
# 1     Pennsylvania State University           Aas Erik        Mathematics
# 2     Pennsylvania State University        Abaci Uygar         Philosophy
# 3     Pennsylvania State University      Abalo Kodzovi          Economics
# 4     Pennsylvania State University       Abar Caitlin  Human Development
# ...                             ...                ...                ...
# 5020  Pennsylvania State University            Zhu Nan  Actuarial Science
# 5021  Pennsylvania State University         Zhu Sencun   Computer Science
# 5022  Pennsylvania State University       Ziegler Greg       Food Science
# 5023  Pennsylvania State University   Zietsma Charlene           Business
# 5024  Pennsylvania State University  Zikatanova Albena        Mathematics
#
#       Rating  Rating Count
# 0        3.5            15
# 1        2.3             3
# 2        4.3            11
# 3        2.8             6
# 4        4.7             3
# ...      ...           ...
# 5020     3.5             4
# 5021     2.3            16
# 5022     2.7             3
# 5023     2.0             1
# 5024     3.0            48
#
# [5025 rows x 5 columns]

# %%
df_ratings = pd.DataFrame(df.groupby(['Department'])['Rating'].mean())

# %%
df_rating_counts = pd.DataFrame(df.groupby(['Department'])['Rating Count'].sum())

# %%
df_rating_counts
# Out:
#                                             Rating Count
# Department
# Accounting                                          1034
# Actuarial Science                                     19
# Aerospace Engineering                                127
# African-American Studies                             182
# Africana Studies                                      30
# Agriculture                                          331
# Animal Science                                       156
# Anthropology                                         578
# Arabic                                                22
# Architectural Engineering                              2
# Architecture                                         265
# Art                                                  305
# Art Education                                         23
# Art History                                          466
# Astronomy                                            763
# Behavioral Sciences                                  350
# Biochemistry                                         157
# Bioethics                                              4
# Biological Sciences                                 2665
# Biology                                               17
# Broadcasting                                          10
# Business                                            2028
# Business Law                                          55
# Chemical Engineering                                 281
# Chemistry                                           2298
# Chinese                                               86
# Civil Engineering                                    175
# Classical  Medieval Studies                           25
# Classical & Medieval Studies                          32
# Classical amp Medieval Studies                         9
# Classics                                             290
# Communication                                       3680
# Communication Arts                                   275
# Communication Disorders                              194
# Comparative Literature                               316
# Computer Science                                    2356
# Counseling                                            23
# Criminal Justice                                     437
# Curriculum  Instruction                                7
# Curriculum & Instruction                              17
# Curriculum amp Instruction                             6
# Design                                                 7
# Developmental Studies                                  6
# Earth Science                                        993
# Economics                                           3726
# Ecosystem Science  Management                          1
# Ecosystem Science & Management                         6
# Education                                            691
# Electrical Engineering                               430
# Engineering                                         2370
# Engineering Science  Mechanics                        14
# Engineering Science amp Mechanics                      5
# Engineering, Science, & Mechanics                     27
# English                                             4676
# Entomology                                            83
# Environmental Engineering                            103
# Ethnic Studies                                        38
# Film                                                  84
# Finance                                              611
# Fine Arts                                            126
# Food Science                                          68
# Forestry                                              86
# French                                               532
# Geography                                            522
# Geological Engineering                                12
# Geology                                              315
# German                                               270
# Graphic Arts                                          66
# Health Administration                                251
# Health Science                                       289
# Hebrew                                                40
# History                                             1300
# Horticulture                                         111
# Hospitality                                          164
# Hotel  Restaurant Management                          10
# Hotel & Restaurant Management                        233
# Hotel amp Restaurant Management                        2
# Human Development                                   1069
# Humanities                                           175
# Industrial Engineering                               348
# Information Science                                  800
# Information Sciences  Technology                     337
# Information Sciences & Technology                    189
# Information Sciences amp Technology                   36
# Information Systems                                  163
# Insurance                                             30
# Integrated Arts                                      148
# International Studies                                 18
# Italian                                              248
# Japanese                                              97
# Jewish Studies                                        56
# Journalism                                            97
# Kinesiology                                          641
# Korean                                                16
# Labor  Employment Relations                           40
# Labor & Employment Relations                         199
# Labor amp Employment Relations                         7
# Landscape Architecture  Regional Planning             10
# Landscape Architecture & Regional Planning            85
# Languages                                            267
# Latin                                                 30
# Law                                                   93
# Literature                                           117
# Management                                           441
# Marketing                                            621
# Materials Engineering                                159
# Mathematics                                         6207
# Mechanical Engineering                               536
# Medicine                                               1
# Meteorology                                          311
# Military Science                                      24
# Mineral Engineering                                  133
# Music                                                547
# Not Specified                                        132
# Nursing                                              148
# Nutrition                                            338
# Philosophy                                           876
# Photography                                           28
# Physical Ed                                          161
# Physics                                              923
# Plant Pathology                                        6
# Political Science                                   1190
# Portuguese                                             2
# Psychology                                          2994
# Real Estate                                           18
# Recreation Parks  Tourism                             48
# Recreation Parks amp Tourism                           2
# Recreation, Parks, & Tourism                          92
# Religion                                             164
# Religious Studies                                    213
# Russian                                               76
# Science                                                5
# Select department                                     48
# Social Science                                       128
# Social Work                                            4
# Sociology                                           1674
# Spanish                                             1265
# Statistics                                          1065
# Supply Chain Management                               23
# Theater                                              364
# Theology                                              32
# University Community                                   1
# Veterinary Sciences                                   84
# Visual Arts                                           63
# Women's Studies                                      418
# Writing                                                6

# %%
df_total = pd.merge(df_ratings, df_rating_counts, on='Department')

# %% [markdown]
# # Cleaning/Export to CSV

# %%
df_total.shape
# Out:
# (117, 2)

# %%
updates = [{'Department':'Classical & Medieval Studies', 'Rating': 4.4821471041756356, 'Rating Count': 66},
           {'Department': 'African Studies', 'Rating': 3.8477987579579627, 'Rating Count': 212},
           {'Department':'Biology', 'Rating': 3.5424170101403556, 'Rating Count': 2682},
           {'Department':'Curriculum Instruction', 'Rating': 4.116825408405727, 'Rating Count': 30},
           {'Department':'Engineering Mechanics', 'Rating': 3.5782609236413156, 'Rating Count': 46},
           {'Department':'Hotel & Restaurant Management', 'Rating': 3.841666678003713, 'Rating Count': 245},
           {'Department':'Information Science Tech', 'Rating': 3.4685114030796003, 'Rating Count': 1362},
           {'Department':'Labor Employment Relations', 'Rating': 3.9464963271008227, 'Rating Count': 246},
           {'Department':'Landscape Architecture & Regional Planning', 'Rating': 3.57796050333663, 'Rating Count': 95},
           {'Department':'Recreation, Parks, & Tourism', 'Rating': 3.9977112855862407, 'Rating Count': 142}
          ]

# %%
df_updates = pd.DataFrame(updates)

# %%
df_updates = df_updates.set_index('Department')

# %%
df_total = df_total.drop(['Classical  Medieval Studies','Biological Sciences', 'Biology','Classical & Medieval Studies','Classical amp Medieval Studies', 'Curriculum  Instruction', 'Curriculum amp Instruction', 'Ecosystem Science  Management', 'Ecosystem Science & Management', 'Engineering Science  Mechanics', 'Engineering Science amp Mechanics', 'Engineering, Science, & Mechanics', 'Hotel  Restaurant Management', 'Hotel & Restaurant Management', 'Hotel amp Restaurant Management', 'Information Sciences  Technology', 'Information Sciences & Technology', 'Information Science', 'Information Sciences amp Technology', 'Labor  Employment Relations', 'Labor & Employment Relations','Labor amp Employment Relations', 'Landscape Architecture  Regional Planning', 'Landscape Architecture & Regional Planning', 'Recreation Parks  Tourism', 'Recreation Parks amp Tourism', 'Recreation, Parks, & Tourism', 'African-American Studies', 'Africana Studies'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-60490d88e6b1> in <module>
# ----> 1 df_total = df_total.drop(['Classical  Medieval Studies','Biological Sciences', 'Biology','Classical & Medieval Studies','Classical amp Medieval Studies', 'Curriculum  Instruction', 'Curriculum amp Instruction', 'Ecosystem Science  Management', 'Ecosystem Science & Management', 'Engineering Science  Mechanics', 'Engineering Science amp Mechanics', 'Engineering, Science, & Mechanics', 'Hotel  Restaurant Management', 'Hotel & Restaurant Management', 'Hotel amp Restaurant Management', 'Information Sciences  Technology', 'Information Sciences & Technology', 'Information Science', 'Information Sciences amp Technology', 'Labor  Employment Relations', 'Labor & Employment Relations','Labor amp Employment Relations', 'Landscape Architecture  Regional Planning', 'Landscape Architecture & Regional Planning', 'Recreation Parks  Tourism', 'Recreation Parks amp Tourism', 'Recreation, Parks, & Tourism', 'African-American Studies', 'Africana Studies'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['Classical  Medieval Studies' 'Biological Sciences' 'Biology'\n 'Classical & Medieval Studies' 'Classical amp Medieval Studies'\n 'Curriculum  Instruction' 'Curriculum amp Instruction'\n 'Ecosystem Science  Management' 'Ecosystem Science & Management'\n 'Engineering Science  Mechanics' 'Engineering Science amp Mechanics'\n 'Engineering, Science, & Mechanics' 'Hotel  Restaurant Management'\n 'Hotel & Restaurant Management' 'Hotel amp Restaurant Management'\n 'Information Sciences  Technology' 'Information Sciences & Technology'\n 'Information Science' 'Information Sciences amp Technology'\n 'Labor  Employment Relations' 'Labor & Employment Relations'\n 'Labor amp Employment Relations'\n 'Landscape Architecture  Regional Planning'\n 'Landscape Architecture & Regional Planning' 'Recreation Parks  Tourism'\n 'Recreation Parks amp Tourism' 'Recreation, Parks, & Tourism'\n 'African-American Studies' 'Africana Studies'] not found in axis"

# %%
df_total.shape
# Out:
# (117, 2)

# %%
df_updates.shape
# Out:
# (10, 2)

# %%
frames1=[df_total,df_updates]

# %%
df_total_updated = pd.concat(frames1)

# %%
df_total_updated
# Out:
#                                               Rating  Rating Count
# Department
# Accounting                                  3.621053          1034
# Actuarial Science                           3.600000            19
# Aerospace Engineering                       3.463636           127
# Agriculture                                 3.909804           331
# Animal Science                              3.561111           156
# Anthropology                                3.419565           578
# Arabic                                      4.500000            22
# Architectural Engineering                   4.000000             2
# Architecture                                3.577778           265
# Art                                         3.608511           305
# Art Education                               3.425000            23
# Art History                                 3.580000           466
# Astronomy                                   3.468421           763
# Behavioral Sciences                         3.552632           350
# Biochemistry                                3.430769           157
# Bioethics                                   4.400000             4
# Broadcasting                                4.900000            10
# Business                                    3.770270          2028
# Business Law                                3.000000            55
# Chemical Engineering                        2.992000           281
# Chemistry                                   3.591139          2298
# Chinese                                     3.793333            86
# Civil Engineering                           3.945946           175
# Classics                                    3.993750           290
# Communication                               3.916049          3680
# Communication Arts                          3.774000           275
# Communication Disorders                     3.690000           194
# Comparative Literature                      3.751429           316
# Computer Science                            3.138947          2356
# Counseling                                  4.300000            23
# Criminal Justice                            3.929730           437
# Curriculum & Instruction                    4.157143            17
# Design                                      2.600000             7
# Developmental Studies                       3.800000             6
# Earth Science                               3.482353           993
# Economics                                   3.204098          3726
# Education                                   3.731868           691
# Electrical Engineering                      3.458333           430
# Engineering                                 3.693717          2370
# English                                     3.844565          4676
# Entomology                                  3.787500            83
# Environmental Engineering                   3.623077           103
# Ethnic Studies                              3.800000            38
# Film                                        4.000000            84
# Finance                                     3.741818           611
# Fine Arts                                   3.658333           126
# Food Science                                3.527273            68
# Forestry                                    3.771429            86
# French                                      4.222973           532
# Geography                                   3.492982           522
# Geological Engineering                      4.000000            12
# Geology                                     3.404348           315
# German                                      4.181633           270
# Graphic Arts                                3.990000            66
# Health Administration                       3.800000           251
# Health Science                              4.036364           289
# Hebrew                                      2.500000            40
# History                                     3.743750          1300
# Horticulture                                3.930000           111
# Hospitality                                 3.827778           164
# Human Development                           3.843056          1069
# Humanities                                  3.422222           175
# Industrial Engineering                      3.166667           348
# Information Systems                         3.370000           163
# Insurance                                   3.800000            30
# Integrated Arts                             3.300000           148
# International Studies                       3.933333            18
# Italian                                     4.223810           248
# Japanese                                    4.390909            97
# Jewish Studies                              3.280000            56
# Journalism                                  4.011111            97
# Kinesiology                                 3.993976           641
# Korean                                      4.214286            16
# Languages                                   4.003571           267
# Latin                                       3.200000            30
# Law                                         3.333333            93
# Literature                                  4.258333           117
# Management                                  3.767742           441
# Marketing                                   3.966667           621
# Materials Engineering                       3.552632           159
# Mathematics                                 3.417738          6207
# Mechanical Engineering                      3.454412           536
# Medicine                                    2.000000             1
# Meteorology                                 3.814286           311
# Military Science                            4.440000            24
# Mineral Engineering                         3.745455           133
# Music                                       4.181250           547
# Not Specified                               3.409091           132
# Nursing                                     3.868000           148
# Nutrition                                   3.726471           338
# Philosophy                                  3.850495           876
# Photography                                 3.400000            28
# Physical Ed                                 3.644444           161
# Physics                                     3.290000           923
# Plant Pathology                             3.100000             6
# Political Science                           3.562121          1190
# Portuguese                                  5.000000             2
# Psychology                                  3.641447          2994
# Real Estate                                 4.800000            18
# Religion                                    3.800000           164
# Religious Studies                           3.550000           213
# Russian                                     3.800000            76
# Science                                     2.900000             5
# Select department                           4.500000            48
# Social Science                              3.690000           128
# Social Work                                 4.166667             4
# Sociology                                   3.810256          1674
# Spanish                                     3.946364          1265
# Statistics                                  3.444828          1065
# Supply Chain Management                     4.362500            23
# Theater                                     4.132432           364
# Theology                                    3.500000            32
# University Community                        5.000000             1
# Veterinary Sciences                         4.085714            84
# Visual Arts                                 3.381818            63
# Women's Studies                             3.705556           418
# Writing                                     4.900000             6
# Classical & Medieval Studies                4.482147            66
# African Studies                             3.847799           212
# Biology                                     3.542417          2682
# Curriculum Instruction                      4.116825            30
# Engineering Mechanics                       3.578261            46
# Hotel & Restaurant Management               3.841667           245
# Information Science Tech                    3.468511          1362
# Labor Employment Relations                  3.946496           246
# Landscape Architecture & Regional Planning  3.577961            95
# Recreation, Parks, & Tourism                3.997711           142

# %%
df_total_updated = df_total_updated.reset_index()

# %%
df_total_updated = df_total_updated.drop(columns='numbers')

# %%
df_total_updated
# Out:
#                                      Department    Rating  Rating Count
# 0                                    Accounting  3.621053          1034
# 1                             Actuarial Science  3.600000            19
# 2                         Aerospace Engineering  3.463636           127
# 3                                   Agriculture  3.909804           331
# 4                                Animal Science  3.561111           156
# 5                                  Anthropology  3.419565           578
# 6                                        Arabic  4.500000            22
# 7                     Architectural Engineering  4.000000             2
# 8                                  Architecture  3.577778           265
# 9                                           Art  3.608511           305
# 10                                Art Education  3.425000            23
# 11                                  Art History  3.580000           466
# 12                                    Astronomy  3.468421           763
# 13                          Behavioral Sciences  3.552632           350
# 14                                 Biochemistry  3.430769           157
# 15                                    Bioethics  4.400000             4
# 16                                 Broadcasting  4.900000            10
# 17                                     Business  3.770270          2028
# 18                                 Business Law  3.000000            55
# 19                         Chemical Engineering  2.992000           281
# 20                                    Chemistry  3.591139          2298
# 21                                      Chinese  3.793333            86
# 22                            Civil Engineering  3.945946           175
# 23                                     Classics  3.993750           290
# 24                                Communication  3.916049          3680
# 25                           Communication Arts  3.774000           275
# 26                      Communication Disorders  3.690000           194
# 27                       Comparative Literature  3.751429           316
# 28                             Computer Science  3.138947          2356
# 29                                   Counseling  4.300000            23
# 30                             Criminal Justice  3.929730           437
# 31                     Curriculum & Instruction  4.157143            17
# 32                                       Design  2.600000             7
# 33                        Developmental Studies  3.800000             6
# 34                                Earth Science  3.482353           993
# 35                                    Economics  3.204098          3726
# 36                                    Education  3.731868           691
# 37                       Electrical Engineering  3.458333           430
# 38                                  Engineering  3.693717          2370
# 39                                      English  3.844565          4676
# 40                                   Entomology  3.787500            83
# 41                    Environmental Engineering  3.623077           103
# 42                               Ethnic Studies  3.800000            38
# 43                                         Film  4.000000            84
# 44                                      Finance  3.741818           611
# 45                                    Fine Arts  3.658333           126
# 46                                 Food Science  3.527273            68
# 47                                     Forestry  3.771429            86
# 48                                       French  4.222973           532
# 49                                    Geography  3.492982           522
# 50                       Geological Engineering  4.000000            12
# 51                                      Geology  3.404348           315
# 52                                       German  4.181633           270
# 53                                 Graphic Arts  3.990000            66
# 54                        Health Administration  3.800000           251
# 55                               Health Science  4.036364           289
# 56                                       Hebrew  2.500000            40
# 57                                      History  3.743750          1300
# 58                                 Horticulture  3.930000           111
# 59                                  Hospitality  3.827778           164
# 60                            Human Development  3.843056          1069
# 61                                   Humanities  3.422222           175
# 62                       Industrial Engineering  3.166667           348
# 63                          Information Systems  3.370000           163
# 64                                    Insurance  3.800000            30
# 65                              Integrated Arts  3.300000           148
# 66                        International Studies  3.933333            18
# 67                                      Italian  4.223810           248
# 68                                     Japanese  4.390909            97
# 69                               Jewish Studies  3.280000            56
# 70                                   Journalism  4.011111            97
# 71                                  Kinesiology  3.993976           641
# 72                                       Korean  4.214286            16
# 73                                    Languages  4.003571           267
# 74                                        Latin  3.200000            30
# 75                                          Law  3.333333            93
# 76                                   Literature  4.258333           117
# 77                                   Management  3.767742           441
# 78                                    Marketing  3.966667           621
# 79                        Materials Engineering  3.552632           159
# 80                                  Mathematics  3.417738          6207
# 81                       Mechanical Engineering  3.454412           536
# 82                                     Medicine  2.000000             1
# 83                                  Meteorology  3.814286           311
# 84                             Military Science  4.440000            24
# 85                          Mineral Engineering  3.745455           133
# 86                                        Music  4.181250           547
# 87                                Not Specified  3.409091           132
# 88                                      Nursing  3.868000           148
# 89                                    Nutrition  3.726471           338
# 90                                   Philosophy  3.850495           876
# 91                                  Photography  3.400000            28
# 92                                  Physical Ed  3.644444           161
# 93                                      Physics  3.290000           923
# 94                              Plant Pathology  3.100000             6
# 95                            Political Science  3.562121          1190
# 96                                   Portuguese  5.000000             2
# 97                                   Psychology  3.641447          2994
# 98                                  Real Estate  4.800000            18
# 99                                     Religion  3.800000           164
# 100                           Religious Studies  3.550000           213
# 101                                     Russian  3.800000            76
# 102                                     Science  2.900000             5
# 103                           Select department  4.500000            48
# 104                              Social Science  3.690000           128
# 105                                 Social Work  4.166667             4
# 106                                   Sociology  3.810256          1674
# 107                                     Spanish  3.946364          1265
# 108                                  Statistics  3.444828          1065
# 109                     Supply Chain Management  4.362500            23
# 110                                     Theater  4.132432           364
# 111                                    Theology  3.500000            32
# 112                        University Community  5.000000             1
# 113                         Veterinary Sciences  4.085714            84
# 114                                 Visual Arts  3.381818            63
# 115                             Women's Studies  3.705556           418
# 116                                     Writing  4.900000             6
# 117                Classical & Medieval Studies  4.482147            66
# 118                             African Studies  3.847799           212
# 119                                     Biology  3.542417          2682
# 120                      Curriculum Instruction  4.116825            30
# 121                       Engineering Mechanics  3.578261            46
# 122               Hotel & Restaurant Management  3.841667           245
# 123                    Information Science Tech  3.468511          1362
# 124                  Labor Employment Relations  3.946496           246
# 125  Landscape Architecture & Regional Planning  3.577961            95
# 126                Recreation, Parks, & Tourism  3.997711           142

# %%
df_total_updated.to_csv('Department_Data.csv')

# %% [markdown]
# # Penn State Global Information

# %%
df_total_updated['Rating Count'].sum()
# Out:
# 65261

# %%
df_total_updated['Rating'].mean()
# Out:
# 3.7564487833401707

# %%
penn_state_global =(3.756449,65261)

# %%
##################
