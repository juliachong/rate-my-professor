# %% [markdown]
# # Imports & Set Up

# %%
import pandas as pd
import scipy.stats as stats
from statsmodels.formula.api import ols
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

# %% [markdown]
# # 50 Schools

# %%
data_schools = pd.read_csv('50_Schools_Data.csv')
data_schools = data_schools.rename(columns={"Rating Count": "RC",'Unnamed: 0': 'CodeKeys'})

# %%
data_schools
# Out:
#     CodeKeys                                        School    Rating      RC
# 0          0                         University of Wyoming  3.726242    3091
# 1          1             University of Wisconsin - Madison  3.785536   47657
# 2          2                      West Virginia University  3.805346   23026
# 3          3                      University of Washington  3.784432   41845
# 4          4                       George Mason University  3.777748   74811
# 5          5                         University of Vermont  3.707608   17457
# 6          6                      Brigham Young University  4.026193   85179
# 7          7       Texas A&M University at College Station  3.718053   31903
# 8          8           University of Tennessee - Knoxville  3.758922   38817
# 9          9                 South Dakota State University  3.655382    4917
# 10        10                  University of South Carolina  3.803050   59665
# ...

# %%
# we are looking at Rating

# %%
anova_rating = ols('Rating~CodeKeys', data=data_schools).fit()
anova_rating.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Rating   R-squared:                       0.083
# Model:                            OLS   Adj. R-squared:                  0.064
# Method:                 Least Squares   F-statistic:                     4.337
# Date:                Tue, 31 Dec 2019   Prob (F-statistic):             0.0427
# Time:                        11:10:06   Log-Likelihood:                 59.207
# No. Observations:                  50   AIC:                            -114.4
# Df Residuals:                      48   BIC:                            -110.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.7716      0.021    179.103      0.000       3.729       3.814
# ...

# %%
anova_table = sm.stats.anova_lm(anova_rating)
print(anova_table)
# Out:
#             df    sum_sq   mean_sq         F    PR(>F)
# CodeKeys   1.0  0.024767  0.024767  4.336672  0.042653
# Residual  48.0  0.274132  0.005711       NaN       NaN

# %%
mc = MultiComparison(data_schools['CodeKeys'], data_schools['Rating'])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3506: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-605d14ae212d> in <module>
#       1 mc = MultiComparison(data_schools['CodeKeys'], data_schools['Rating'])
# ----> 2 mc_results = mc.tukeyhsd()
#       3 print(mc_results)
#
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/sandbox/stats/multicomp.py in tukeyhsd(self, alpha)
#    1003         # res contains: 0:(idx1, idx2), 1:reject, 2:meandiffs, 3: std_pairs,
#    1004         # 4:confint, 5:q_crit, 6:df_total, 7:reject2, 8: pvals
# ...

# %%
data_schools['Rating'].corr(data_schools['RC'])

# %% [markdown]
# # Departments (PSU)

# %%
data_department = pd.read_csv('Department_Data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-fed04552f014> in <module>
# ----> 1 data_department = pd.read_csv('Department_Data.csv')
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
data_department.drop(columns='Unnamed: 0')

# %%
data_department=data_department.rename(columns={'Unnamed: 0': 'CodeKeys'})

# %%
data_department
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e57baa5b0f9f> in <module>
# ----> 1 data_department
#
# NameError: name 'data_department' is not defined

# %%
anova_rating = ols('Rating~CodeKeys', data=data_department).fit()
anova_rating.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2e16023e8a65> in <module>
# ----> 1 anova_rating = ols('Rating~CodeKeys', data=data_department).fit()
#       2 anova_rating.summary()
#
# NameError: name 'data_department' is not defined

# %%
anova_table = sm.stats.anova_lm(anova_rating)
print(anova_table)
# Out:
#             df    sum_sq   mean_sq         F    PR(>F)
# CodeKeys   1.0  0.024767  0.024767  4.336672  0.042653
# Residual  48.0  0.274132  0.005711       NaN       NaN

# %%
mc = MultiComparison(data_department['CodeKeys'], data_department['Rating'])
mc_results = mc.tukeyhsd()
print(mc_results.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e02b620d4707> in <module>
# ----> 1 mc = MultiComparison(data_department['CodeKeys'], data_department['Rating'])
#       2 mc_results = mc.tukeyhsd()
#       3 print(mc_results.summary())
#
# NameError: name 'data_department' is not defined

# %%
https://www.ratemyprofessors.com/filter/professor/?&page=1&filter=teacherlastname_sort_s+asc&query=*%3A*&queryoption=TEACHER&queryBy=schoolId&sid=758
